# %% [markdown]
# Code to get and save the Ethnologue language phlyogen

# %%
import json
import re
import sys
import urllib
import time
import gzip

import requests
import lxml.html
from lxml import etree

def get_family(path):
    print("getting " + path)
    r = requests.get("https://www.ethnologue.com" + path)
    html = lxml.html.fromstring(r.text, "lxml")
    return path, parse_family(html)

def parse_family(html):
    try:
        ethn_tree = html.cssselect("div.view-family.view-id-family.ethn-tree")[0]
    except IndexError as e:
        print(html)
        raise e
    divs = ethn_tree.findall("div")
    # flat tree
    if len(divs) == 1:
        return parse_family1(divs[0])
    elif len(divs) == 2:
        return parse_family2(divs)
    else:
        print("Unknown number of divs in ", path)

def parse_subgroup_text(x):
    data = dict(zip(('name', ), re.match(r"(.*) \((\d+)\)$", x).groups()))
    data["is_language"] = False
    return data
                    
def parse_lang(el):
    data = {}
    path = el.xpath('.//a[contains(@href, "/language/")]')[0].get("href")
    data["name"] = el.xpath(".//span[contains(@class, 'field-content')]/text()[1]")[0].strip()
    data["is_language"] = True
    data["id"] = el.xpath(".//a[contains(@href, '/language/')]/text()")[0][1:-1]
    country = el.xpath(".//a[contains(@href, '/country/')]")[0].get("href")
    data['country'] = re.search('/country/([A-Z]{2})', country).group(1)
    data['children'] = {}
    return (path, data)

def parse_family1(el):
    """ Parse language family with no-subgroups """
    langs = el.cssselect("li.lang-indent")
    data = parse_subgroup_text(el.cssselect("div.views-field-name-1 > span.field-content")[0].text)
    data['children'] = dict(parse_lang(x) for x in langs)
    return data

def parse_family2(divs):
    """ Parse language family with subgroups """
    data = parse_subgroup_text(divs[0].
      cssselect("div.views-field-name-1 > span.field-content")[0].text)
    item_list = divs[1].xpath("div[@class='item-list']/ul")[0]
    data['children'] = parse_item_list(item_list)
    return data

def parse_item_list(el):
    return dict(parse_item(li) for li in el.findall("li"))

def parse_item(el):
    path = el.find("a").get("href")
    data = parse_subgroup_text(el.find("a").text.strip())
    data['id'] = urllib.parse.unquote(path.split('/')[2])
    print(path)
    langs = el.xpath("div[contains(@class, 'view-id-language')]//li[contains(@class, 'lang-indent')]")
    data['children'] = {}
    if len(langs):
        lang_data = dict(parse_lang(x) for x in langs)
        print(str(len(lang_data)) + " languages")
        data['children'].update(lang_data)
    item_list = el.xpath("div[@class='item-list']")
    if len(item_list):
        subgroup_data = dict(parse_item_list(item_list[0].find("ul")))
        data['children'].update(subgroup_data)
    return (path, data)

def get_all_families():
    r = requests.get("https://www.ethnologue.com/browse/families")
    html = lxml.html.fromstring(r.text)
    families = [a.get("href") for a in html.xpath("//a[contains(@href, '/subgroups/')]")]
    out = {}
    for family in families:
        k, v = get_family(family)
        out[k] = v
        time.sleep(10)
    return out

# %%
data = get_all_families()
# Out:
# getting /subgroups/afro-asiatic
# /subgroups/berber
# /subgroups/eastern-3
# /subgroups/awjila-sokna
# 2 languages
# /subgroups/siwa
# 1 languages
# /subgroups/northern-6
# 1 languages
# /subgroups/atlas
# 4 languages
# /subgroups/kabyle
# 1 languages
# /subgroups/zenati
# /subgroups/east-7
# 3 languages
# /subgroups/ghomara
# 1 languages
# /subgroups/mzab-wargla
# 4 languages
# /subgroups/riff
# 2 languages
# /subgroups/shawiya
# 1 languages
# /subgroups/tidikelt
# 1 languages
# /subgroups/tamasheq
# /subgroups/northern-12
# 1 languages
# /subgroups/southern-16
# 3 languages
# /subgroups/zenaga
# 1 languages
# /subgroups/chadic
# /subgroups/biu-mandara
# /subgroups/a
# /subgroups/a1-0
# /subgroups/eastern-31
# 3 languages
# /subgroups/western-30
# 2 languages
# /subgroups/a2-1
# 1 languages
# /subgroups/1-2
# 4 languages
# /subgroups/2-2
# 3 languages
# /subgroups/a3
# 5 languages
# /subgroups/a4
# /subgroups/lamang
# 3 languages
# /subgroups/mandara-proper
# /subgroups/glavda
# 5 languages
# /subgroups/mandara
# 1 languages
# /subgroups/podoko
# 1 languages
# /subgroups/a5
# 18 languages
# /subgroups/a6
# 1 languages
# /subgroups/a7
# 6 languages
# /subgroups/a8
# 12 languages
# /subgroups/b
# /subgroups/b1
# 1 languages
# /subgroups/buduma
# 1 languages
# /subgroups/jina
# 2 languages
# /subgroups/kotoko-proper
# /subgroups/north-10
# 4 languages
# /subgroups/south-12
# 2 languages
# /subgroups/b2
# 3 languages
# /subgroups/c
# 1 languages
# /subgroups/east-0
# /subgroups/a-0
# /subgroups/a1
# 1 languages
# /subgroups/1-1
# 4 languages
# /subgroups/2-0
# 4 languages
# /subgroups/a2
# /subgroups/1-0
# 3 languages
# /subgroups/2-1
# 3 languages
# /subgroups/a3-0
# 2 languages
# /subgroups/b-0
# /subgroups/b1-0
# /subgroups/1
# 8 languages
# /subgroups/2
# 6 languages
# /subgroups/b2-0
# 1 languages
# /subgroups/b3
# 4 languages
# /subgroups/masa
# 8 languages
# /subgroups/west-2
# /subgroups/a-1
# /subgroups/a1-1
# 2 languages
# /subgroups/a2-0
# /subgroups/bole
# /subgroups/bole-proper
# 13 languages
# /subgroups/karekare
# 1 languages
# /subgroups/tangale
# /subgroups/dera
# 1 languages
# /subgroups/tangale-proper
# 6 languages
# /subgroups/a3-1
# /subgroups/angas-proper
# /subgroups/1-3
# 6 languages
# /subgroups/2-3
# 5 languages
# /subgroups/yiwom
# 1 languages
# /subgroups/a4-0
# /subgroups/fyer
# 2 languages
# /subgroups/ron-proper
# 5 languages
# /subgroups/b-1
# /subgroups/b1-1
# /subgroups/bade-proper
# 2 languages
# /subgroups/duwai
# 1 languages
# /subgroups/b2-1
# 10 languages
# /subgroups/b3-0
# 1 languages
# /subgroups/boghom
# 3 languages
# /subgroups/eastern-32
# 1 languages
# /subgroups/guruntum
# 4 languages
# /subgroups/zaar-proper
# 6 languages
# /subgroups/cushitic
# /subgroups/central-3
# /subgroups/eastern-12
# 1 languages
# /subgroups/northern-14
# 1 languages
# /subgroups/southern-11
# 1 languages
# /subgroups/western-10
# 1 languages
# /subgroups/east-1
# 1 languages
# /subgroups/dullay
# 2 languages
# /subgroups/highland
# 7 languages
# /subgroups/konso-gidole
# 3 languages
# /subgroups/oromo
# 5 languages
# /subgroups/rendille-boni
# 2 languages
# /subgroups/saho-afar
# 2 languages
# /subgroups/somali
# 6 languages
# /subgroups/western-omo-tana
# 4 languages
# /subgroups/yaaku
# 1 languages
# /subgroups/north-1
# 1 languages
# /subgroups/south-1
# 7 languages
# /subgroups/egyptian
# 1 languages
# /subgroups/omotic
# /subgroups/north-0
# /subgroups/dizoid
# 3 languages
# /subgroups/gonga-gimojan
# /subgroups/gimojan
# /subgroups/janjero
# 1 languages
# /subgroups/ometo-gimira
# /subgroups/chara
# 1 languages
# /subgroups/gimira
# 1 languages
# /subgroups/ometo
# 1 languages
# /subgroups/central-34
# 7 languages
# /subgroups/east-12
# 3 languages
# /subgroups/west-10
# 1 languages
# /subgroups/gonga
# /subgroups/central-19
# 1 languages
# /subgroups/north-9
# 1 languages
# /subgroups/south-8
# 2 languages
# /subgroups/mao
# 4 languages
# /subgroups/south-0
# 5 languages
# /subgroups/semitic
# /subgroups/central-2
# 1 languages
# /subgroups/aramaic
# /subgroups/eastern-22
# 1 languages
# /subgroups/central-20
# /subgroups/northeastern-1
# 12 languages
# /subgroups/northwestern-5
# 2 languages
# /subgroups/mandaic
# 2 languages
# /subgroups/western-23
# 2 languages
# /subgroups/south-2
# /subgroups/arabic
# 35 languages
# /subgroups/canaanite
# 3 languages
# /subgroups/south
# /subgroups/ethiopian
# /subgroups/north-4
# 4 languages
# /subgroups/south-4
# /subgroups/outer
# /subgroups/n-group
# 1 languages
# /subgroups/tt-group
# 4 languages
# /subgroups/transversal
# /subgroups/amharic-argobba
# 2 languages
# /subgroups/harari-east-gurage
# 4 languages
# /subgroups/south-arabian
# 6 languages
# /subgroups/unclassified-1
# 1 languages
# getting /subgroups/eastern-trans-fly
# getting /subgroups/matacoan
# /subgroups/chorote
# 2 languages
# /subgroups/mataco
# 3 languages
# getting /subgroups/siouan-catawban
# /subgroups/catawban
# 1 languages
# /subgroups/siouan
# 1 languages
# /subgroups/mississippi-valley-ohio-valley-siouan
# /subgroups/mississippi-valley-siouan
# /subgroups/chiwere-winnebago
# 2 languages
# /subgroups/dakota
# 4 languages
# /subgroups/dhegihan
# 4 languages
# /subgroups/missouri-river-siouan
# 2 languages
# getting /subgroups/algic
# /subgroups/algonquian
# 5 languages
# /subgroups/arapaho
# 2 languages
# /subgroups/cree-montagnais
# 9 languages
# /subgroups/eastern-algonquian
# 6 languages
# /subgroups/abenaki
# 2 languages
# /subgroups/delaware
# 2 languages
# /subgroups/nanticoke-conoy
# 2 languages
# /subgroups/fox
# 2 languages
# /subgroups/ojibwa-potawatomi
# 9 languages
# /subgroups/unclassified-10
# 1 languages
# /subgroups/ritwan
# 2 languages
# getting /subgroups/eskimo-aleut
# /subgroups/aleut
# 1 languages
# /subgroups/eskimo
# /subgroups/inuit-inupiaq
# 5 languages
# /subgroups/yupik
# 3 languages
# /subgroups/alaskan-yupik
# 2 languages
# getting /subgroups/maxakalian
# getting /subgroups/skou
# /subgroups/i%E2%80%99saka
# 1 languages
# /subgroups/skou-serra-piore
# /subgroups/nuclear-skou
# /subgroups/eastern-skou
# 2 languages
# /subgroups/skou-0
# 1 languages
# /subgroups/serra-hills
# /subgroups/piore-river
# 1 languages
# /subgroups/puari
# 1 languages
# /subgroups/rawo-main-serra
# /subgroups/main-serra
# 1 languages
# /subgroups/rawo
# 1 languages
# getting /subgroups/amto-musan
# getting /subgroups/eyak-athabaskan
# /subgroups/athabaskan
# /subgroups/apachean
# 1 languages
# /subgroups/apache
# 5 languages
# /subgroups/northern-athabaskan
# 18 languages
# /subgroups/carrier
# 2 languages
# /subgroups/slavey-hare
# 2 languages
# /subgroups/tahltan
# 3 languages
# /subgroups/tuchone
# 2 languages
# /subgroups/pacific-coast-athabaskan
# /subgroups/california-athabaskan
# 4 languages
# /subgroups/oregon-athabaskan
# 1 languages
# /subgroups/tolowa-chetco
# 2 languages
# /subgroups/tututni-chasta-costa-coquille
# 2 languages
# /subgroups/tlingit
# 1 languages
# getting /subgroups/mayan
# /subgroups/huastecan
# 1 languages
# /subgroups/huastec
# 1 languages
# /subgroups/yucatecan-core-mayan
# /subgroups/core-mayan
# /subgroups/cholan-tzeltalan
# /subgroups/cholan
# /subgroups/chol-chontal
# 1 languages
# /subgroups/chol
# 1 languages
# /subgroups/chorti-cholti
# 1 languages
# /subgroups/tzeltalan
# /subgroups/tzeltal
# 1 languages
# /subgroups/tzotzil
# 1 languages
# /subgroups/k%E2%80%99ichean-mamean
# /subgroups/k%E2%80%99ichean
# 2 languages
# /subgroups/poqom-k%E2%80%99ichean
# /subgroups/core-k%E2%80%99ichean
# 4 languages
# /subgroups/kaqchikel-tz%E2%80%99utujil
# 2 languages
# /subgroups/poqom
# /subgroups/poqomam
# 1 languages
# /subgroups/poqomchi%E2%80%99
# 1 languages
# /subgroups/mamean
# /subgroups/awakateko-ixil
# 2 languages
# /subgroups/teco-mam
# 2 languages
# /subgroups/q%E2%80%99anjob%E2%80%99alan-chujean
# /subgroups/chujean
# 2 languages
# /subgroups/q%E2%80%99anjob%E2%80%99alan
# 1 languages
# /subgroups/q%E2%80%99anjob%E2%80%99al-akateko-jakalteko
# 3 languages
# /subgroups/yucatecan
# /subgroups/mopan-itz%C3%A1
# 2 languages
# /subgroups/yucatec-lacandon
# 2 languages
# getting /subgroups/somahai
# getting /subgroups/andamanese
# /subgroups/great-andamanese
# 1 languages
# /subgroups/central-4
# 6 languages
# /subgroups/northern-7
# 4 languages
# /subgroups/south-andamanese
# 3 languages
# getting /subgroups/fas
# getting /subgroups/maybrat
# getting /subgroups/south-bougainville
# /subgroups/buin
# 3 languages
# /subgroups/nasioi
# 6 languages
# getting /subgroups/arafundi
# getting /subgroups/guajiboan
# /subgroups/guajibo
# 3 languages
# getting /subgroups/misumalpan
# /subgroups/sumu-cacaopera-matagalpa
# /subgroups/cacaopera-matagalpa
# 2 languages
# getting /subgroups/south-central-papuan
# /subgroups/morehead-upper-maro
# /subgroups/nambu
# 6 languages
# /subgroups/tonda
# 10 languages
# /subgroups/yey
# 1 languages
# /subgroups/pahoturi
# 2 languages
# /subgroups/waia
# 1 languages
# /subgroups/yelmek-maklew
# 2 languages
# getting /subgroups/arai-left-may
# getting /subgroups/guaykuruan
# /subgroups/guaykur%C3%BA
# 1 languages
# /subgroups/southern-6
# 3 languages
# getting /subgroups/miwok-costanoan
# /subgroups/costanoan
# 2 languages
# /subgroups/miwokan
# /subgroups/eastern-miwokan
# 1 languages
# /subgroups/sierra-miwok
# 3 languages
# /subgroups/western-miwokan
# 2 languages
# getting /subgroups/tacanan
# /subgroups/chama
# 2 languages
# /subgroups/tacana
# 3 languages
# getting /subgroups/arauan
# /subgroups/jamamadi
# 1 languages
# getting /subgroups/haida
# getting /subgroups/mixe-zoquean
# /subgroups/mixean
# 2 languages
# /subgroups/oaxaca-mixean
# 3 languages
# /subgroups/lowland-mixe
# 3 languages
# /subgroups/midland-mixe
# 1 languages
# /subgroups/south-highland-mixe
# 1 languages
# /subgroups/zoquean
# 1 languages
# /subgroups/chiapas-zoquean
# 2 languages
# /subgroups/northeast-zoque
# 1 languages
# /subgroups/gulf-zoquean
# 3 languages
# getting /subgroups/tai-kadai
# /subgroups/hlai
# 2 languages
# /subgroups/kam-tai
# /subgroups/kam-sui
# 12 languages
# /subgroups/lakkja
# 2 languages
# /subgroups/tai
# 4 languages
# /subgroups/central-9
# 10 languages
# /subgroups/northern-18
# 13 languages
# /subgroups/southwestern
# 31 languages
# /subgroups/kra
# /subgroups/central-kra
# 1 languages
# /subgroups/eastern-kra
# 7 languages
# /subgroups/western-kra
# 8 languages
# getting /subgroups/australian
# /subgroups/bunaban
# 2 languages
# /subgroups/daly
# /subgroups/bringen-wagaydy
# /subgroups/bringen
# 7 languages
# /subgroups/wagaydy
# 5 languages
# /subgroups/malagmalag
# /subgroups/daly-proper
# 2 languages
# /subgroups/malagmalag-proper
# 2 languages
# /subgroups/marriammu
# 1 languages
# /subgroups/murrinh-patha
# 2 languages
# /subgroups/djamindjungan
# 2 languages
# /subgroups/djeragan
# 3 languages
# /subgroups/giimbiyu
# 3 languages
# /subgroups/gunwingguan
# /subgroups/burarran
# 4 languages
# /subgroups/djauanic
# 1 languages
# /subgroups/enindhilyagwa
# 3 languages
# /subgroups/gagudjuan
# 1 languages
# /subgroups/gungaraganyan
# 1 languages
# /subgroups/gunwinggic
# 2 languages
# /subgroups/mangarayic
# 1 languages
# /subgroups/maran
# 1 languages
# /subgroups/alawic
# 1 languages
# /subgroups/mara
# 2 languages
# /subgroups/ngalkbun
# 1 languages
# /subgroups/rembargic
# 2 languages
# /subgroups/wagiman
# 1 languages
# /subgroups/warayan
# 1 languages
# /subgroups/yangmanic
# 3 languages
# /subgroups/laragiyan
# 1 languages
# /subgroups/limilngan-wulna
# 2 languages
# /subgroups/nyulnyulan
# 9 languages
# /subgroups/pama-nyungan
# 4 languages
# /subgroups/arandic
# 8 languages
# /subgroups/baagandji
# 1 languages
# /subgroups/bandjalangic
# 4 languages
# /subgroups/bungandidj
# 2 languages
# /subgroups/durubulic
# 3 languages
# /subgroups/dyangadi
# 2 languages
# /subgroups/dyirbalic
# 4 languages
# /subgroups/flinders-island
# 1 languages
# /subgroups/galgadungic
# 3 languages
# /subgroups/gumbaynggiric
# 2 languages
# /subgroups/guugu-yimidhirr
# 2 languages
# /subgroups/kala-lagaw-ya
# 1 languages
# /subgroups/karnic
# 10 languages
# /subgroups/karna
# 6 languages
# /subgroups/ngura
# 5 languages
# /subgroups/palku
# 4 languages
# /subgroups/kulin
# 11 languages
# /subgroups/western-15
# 1 languages
# /subgroups/lardil
# 1 languages
# /subgroups/maric
# 22 languages
# /subgroups/mbara
# 1 languages
# /subgroups/muruwaric
# 1 languages
# /subgroups/ngarinyeric-yithayithic
# 3 languages
# /subgroups/pallanganmiddang
# 1 languages
# /subgroups/paman
# 5 languages
# /subgroups/central-pama
# 1 languages
# /subgroups/coastal-pama
# 1 languages
# /subgroups/flinders-pama
# 1 languages
# /subgroups/lamalamic
# 2 languages
# /subgroups/mayabic
# 6 languages
# /subgroups/mbariman
# 2 languages
# /subgroups/middle-pama
# 15 languages
# /subgroups/norman-pama
# 3 languages
# /subgroups/northeastern-pama
# 3 languages
# /subgroups/northern-pama
# 10 languages
# /subgroups/rarmul-pama
# 3 languages
# /subgroups/southern-pama
# 2 languages
# /subgroups/southwestern-pama
# 3 languages
# /subgroups/umbindhamuic
# 1 languages
# /subgroups/western-pama
# 1 languages
# /subgroups/yir-yoront
# 2 languages
# /subgroups/south-west
# 2 languages
# /subgroups/coastal-ngayarda
# 8 languages
# /subgroups/dhalandji
# 2 languages
# /subgroups/inland-ngayarda
# 7 languages
# /subgroups/kanyara
# 2 languages
# /subgroups/malgana
# 1 languages
# /subgroups/mangala
# 1 languages
# /subgroups/marngu
# 2 languages
# /subgroups/mirning
# 2 languages
# /subgroups/ngarga
# 2 languages
# /subgroups/ngumbin
# 7 languages
# /subgroups/nyungar
# 8 languages
# /subgroups/wadjari
# 2 languages
# /subgroups/wati
# 12 languages
# /subgroups/yinggarda
# 2 languages
# /subgroups/yura
# 9 languages
# /subgroups/wagaya-warluwaric
# /subgroups/warluwara-thawa
# 3 languages
# /subgroups/waka-kabic
# 2 languages
# /subgroups/kingkel
# 1 languages
# /subgroups/miyan
# 2 languages
# /subgroups/than
# 1 languages
# /subgroups/warumungic
# 1 languages
# /subgroups/wiradhuric
# 3 languages
# /subgroups/worimi
# 2 languages
# /subgroups/yalandyic
# 3 languages
# /subgroups/yanyuwan
# 1 languages
# /subgroups/yarli
# 3 languages
# /subgroups/yidinic
# 2 languages
# /subgroups/yotayotic
# 2 languages
# /subgroups/yugambal
# 1 languages
# /subgroups/yuin
# 10 languages
# /subgroups/yuulngu
# 1 languages
# /subgroups/dhangu
# 2 languages
# /subgroups/dhuwal
# 7 languages
# /subgroups/djinang
# 2 languages
# /subgroups/tangic
# 3 languages
# /subgroups/tiwian
# 1 languages
# /subgroups/umbugarla-ngumbur
# 2 languages
# /subgroups/west-barkly
# 3 languages
# /subgroups/worrorran
# 6 languages
# /subgroups/ngarinyinic
# 1 languages
# /subgroups/western-worrorran
# 5 languages
# /subgroups/yanyi
# 2 languages
# /subgroups/yiwaidjan
# /subgroups/amaragic
# 1 languages
# /subgroups/margic
# 1 languages
# /subgroups/yiwaidjic
# 5 languages
# getting /subgroups/har%C3%A1kmbut
# getting /subgroups/mixed-language
# /subgroups/armenian-romani
# 1 languages
# /subgroups/bantu-cushitic
# 1 languages
# /subgroups/basque-romani
# 1 languages
# /subgroups/cakchiquel-quich%C3%A9
# 1 languages
# /subgroups/cebuano-spanish-english
# 1 languages
# /subgroups/chinese-tibetan-bonan-mongour
# 1 languages
# /subgroups/danish-romani
# 1 languages
# /subgroups/english-romani
# 1 languages
# /subgroups/french-cree
# 1 languages
# /subgroups/german-yiddish-romani-rotwelsch
# 1 languages
# /subgroups/greek-romani
# 1 languages
# /subgroups/gurindji-kriol
# 1 languages
# /subgroups/iberian-romani
# 1 languages
# /subgroups/irish-undocumented
# 1 languages
# /subgroups/norwegian-romani
# 1 languages
# /subgroups/russian-aleut
# 1 languages
# /subgroups/serbian-romani
# 1 languages
# /subgroups/songhay-berber
# 1 languages
# /subgroups/spanish-quichua
# 1 languages
# /subgroups/swedish-romani
# 1 languages
# /subgroups/yapese-ulithi
# 1 languages
# /subgroups/zulu-bantu
# 1 languages
# getting /subgroups/takelman
# getting /subgroups/austro-asiatic
# /subgroups/mon-khmer
# /subgroups/aslian
# /subgroups/jah-hut
# 1 languages
# /subgroups/north-aslian
# /subgroups/chewong
# 1 languages
# /subgroups/eastern-23
# 4 languages
# /subgroups/tonga
# 1 languages
# /subgroups/western-22
# 2 languages
# /subgroups/senoic
# 5 languages
# /subgroups/south-aslian
# 4 languages
# /subgroups/eastern-mon-khmer
# /subgroups/bahnaric
# /subgroups/central-bahnaric
# 4 languages
# /subgroups/east-bahnaric
# 1 languages
# /subgroups/north-bahnaric
# 2 languages
# /subgroups/east-10
# 2 languages
# /subgroups/west-7
# 2 languages
# /subgroups/duan
# 1 languages
# /subgroups/jeh-halang
# 2 languages
# /subgroups/rengao
# 1 languages
# /subgroups/sedang-todrah
# /subgroups/sedang
# 2 languages
# /subgroups/todrah-monom
# 2 languages
# /subgroups/south-bahnaric
# 1 languages
# /subgroups/sre-mnong
# /subgroups/mnong
# /subgroups/eastern-mnong
# 1 languages
# /subgroups/southern-central-mnong
# 3 languages
# /subgroups/sre
# 2 languages
# /subgroups/stieng-chrau
# 2 languages
# /subgroups/west-bahnaric
# /subgroups/brao-kravet
# 4 languages
# /subgroups/laven
# 1 languages
# /subgroups/nyaheun
# 1 languages
# /subgroups/oi
# 2 languages
# /subgroups/katuic
# /subgroups/central-katuic
# /subgroups/ta%E2%80%99oih
# 4 languages
# /subgroups/east-katuic
# /subgroups/katu-pacoh
# 5 languages
# /subgroups/ngeq-nkriang
# 2 languages
# /subgroups/west-katuic
# /subgroups/bru
# 6 languages
# /subgroups/kuay
# 2 languages
# /subgroups/khmer
# 2 languages
# /subgroups/pearic
# /subgroups/eastern-20
# 1 languages
# /subgroups/western-19
# /subgroups/chong
# 2 languages
# /subgroups/samre
# 2 languages
# /subgroups/suoy
# 1 languages
# /subgroups/monic
# 1 languages
# /subgroups/nicobar
# /subgroups/car
# 1 languages
# /subgroups/chowra-teressa
# 2 languages
# /subgroups/great-nicobar
# 1 languages
# /subgroups/nancowry
# 1 languages
# /subgroups/shom-peng
# 1 languages
# /subgroups/northern-mon-khmer
# /subgroups/khasian
# 4 languages
# /subgroups/khmuic
# /subgroups/khao
# 1 languages
# /subgroups/mal-khmu%E2%80%99
# /subgroups/khmu%E2%80%99
# 3 languages
# /subgroups/mal-prai
# 2 languages
# /subgroups/mlabri
# 1 languages
# /subgroups/xinh-mul
# 2 languages
# /subgroups/mang
# 1 languages
# /subgroups/palaungic
# /subgroups/eastern-palaungic
# /subgroups/angkuic
# 9 languages
# /subgroups/bit-khang
# 2 languages
# /subgroups/lametic
# 2 languages
# /subgroups/waic
# /subgroups/bulang
# 2 languages
# /subgroups/lawa
# 2 languages
# /subgroups/wa
# 3 languages
# /subgroups/western-palaungic
# /subgroups/danau
# 1 languages
# /subgroups/palaung
# 3 languages
# /subgroups/riang
# 2 languages
# /subgroups/palyu
# 2 languages
# /subgroups/southern-monic
# 1 languages
# /subgroups/unclassified-6
# 2 languages
# /subgroups/viet-muong
# /subgroups/chut
# 3 languages
# /subgroups/cuoi
# 2 languages
# /subgroups/muong
# 3 languages
# /subgroups/thavung
# 1 languages
# /subgroups/vietnamese
# 1 languages
# /subgroups/munda
# /subgroups/north-munda
# /subgroups/kherwari
# 3 languages
# /subgroups/mundari
# 8 languages
# /subgroups/santali
# 3 languages
# /subgroups/korku
# 1 languages
# /subgroups/south-munda
# /subgroups/kharia-juang
# 2 languages
# /subgroups/koraput-munda
# /subgroups/gutob-remo-geta%E2%80%99
# /subgroups/geta%E2%80%99
# 1 languages
# /subgroups/gutob-remo
# 2 languages
# /subgroups/sora-juray-gorum
# /subgroups/gorum
# 1 languages
# /subgroups/sora-juray
# 2 languages
# getting /subgroups/hmong-mien
# /subgroups/hmongic
# /subgroups/bunu
# 4 languages
# /subgroups/chuanqiandian
# 22 languages
# /subgroups/pa-hng
# 1 languages
# /subgroups/qiandong
# 3 languages
# /subgroups/xiangxi
# 2 languages
# /subgroups/ho-nte
# 1 languages
# /subgroups/mienic
# /subgroups/biao-jiao
# 1 languages
# /subgroups/mian-jin
# 3 languages
# /subgroups/zaomin
# 1 languages
# getting /subgroups/mongol-langam
# getting /subgroups/tarascan
# getting /subgroups/austronesian
# /subgroups/atayalic
# 2 languages
# /subgroups/bunun
# 1 languages
# /subgroups/east-formosan
# /subgroups/central-6
# 2 languages
# /subgroups/northern-9
# 2 languages
# /subgroups/southwest-0
# 1 languages
# /subgroups/malayo-polynesian
# 1 languages
# /subgroups/bali-sasak-sumbawa
# 1 languages
# /subgroups/sasak-sumbawa
# 2 languages
# /subgroups/bashiic
# /subgroups/ivatan
# 2 languages
# /subgroups/yami
# 1 languages
# /subgroups/bilic
# 2 languages
# /subgroups/blaan
# 2 languages
# /subgroups/tboli
# 1 languages
# /subgroups/celebic
# /subgroups/eastern-13
# /subgroups/saluan-banggai
# /subgroups/eastern-29
# 2 languages
# /subgroups/western-26
# 1 languages
# /subgroups/saluanic
# 3 languages
# /subgroups/southeastern-1
# /subgroups/bungku-tolaki
# /subgroups/eastern-37
# /subgroups/east-coast
# 4 languages
# /subgroups/kulisusu
# 3 languages
# /subgroups/southwest-3
# 1 languages
# /subgroups/western-36
# /subgroups/interior-0
# 3 languages
# /subgroups/west-coast-0
# 4 languages
# /subgroups/muna-buton
# /subgroups/nuclear-muna-buton
# /subgroups/buton
# /subgroups/east-buton
# 2 languages
# /subgroups/west-buton
# 1 languages
# /subgroups/munan
# 1 languages
# /subgroups/munic
# 1 languages
# /subgroups/western-46
# 4 languages
# /subgroups/tukangbesi-bonerate
# 3 languages
# /subgroups/kaili-pamona
# /subgroups/northern-22
# /subgroups/kaili
# 8 languages
# /subgroups/pamona
# 2 languages
# /subgroups/southern-22
# 3 languages
# /subgroups/badaic
# 3 languages
# /subgroups/tomini-tolitoli
# /subgroups/tolitoli
# 2 languages
# /subgroups/tomini
# /subgroups/northern-28
# 3 languages
# /subgroups/southern-29
# 5 languages
# /subgroups/wotu-wolio
# 1 languages
# /subgroups/kalao
# 2 languages
# /subgroups/wolio-kamaru
# 2 languages
# /subgroups/central-luzon
# /subgroups/pampangan
# 1 languages
# /subgroups/sambalic
# 8 languages
# /subgroups/sinauna
# 1 languages
# /subgroups/central-eastern-malayo-polynesian
# /subgroups/aru
# 14 languages
# /subgroups/babar
# /subgroups/north-5
# 3 languages
# /subgroups/south-5
# /subgroups/masela-south-babar
# 5 languages
# /subgroups/southwest-babar
# 3 languages
# /subgroups/bima-lembata
# 30 languages
# /subgroups/central-maluku
# /subgroups/ambelau
# 1 languages
# /subgroups/buru
# 3 languages
# /subgroups/east-6
# 1 languages
# /subgroups/banda-geser
# 1 languages
# /subgroups/geser-gorom
# 3 languages
# /subgroups/seram
# /subgroups/bobot
# 1 languages
# /subgroups/east-seram
# 1 languages
# /subgroups/manusela-seti
# 5 languages
# /subgroups/masiwang
# 1 languages
# /subgroups/nunusaku
# /subgroups/kayeli
# 1 languages
# /subgroups/piru-bay
# 1 languages
# /subgroups/east-14
# 3 languages
# /subgroups/seram-straits
# /subgroups/ambon
# 3 languages
# /subgroups/solehua
# 1 languages
# /subgroups/uliase
# /subgroups/hatuhaha
# /subgroups/elpaputi
# 2 languages
# /subgroups/saparua
# 2 languages
# /subgroups/kamarian
# 1 languages
# /subgroups/west-12
# /subgroups/asilulu
# 2 languages
# /subgroups/hoamoal
# 2 languages
# /subgroups/three-rivers
# 1 languages
# /subgroups/amalumute
# /subgroups/northwest-seram
# 2 languages
# /subgroups/hulung
# 1 languages
# /subgroups/loun
# 1 languages
# /subgroups/ulat-inai
# 2 languages
# /subgroups/wemale
# 1 languages
# /subgroups/sawai-nuaulu
# 3 languages
# /subgroups/sula
# 2 languages
# /subgroups/taliabo
# 2 languages
# /subgroups/eastern-malayo-polynesian
# /subgroups/oceanic
# /subgroups/admiralty-islands
# /subgroups/eastern-40
# /subgroups/manus
# /subgroups/east-16
# 12 languages
# /subgroups/mokoreng-loniu
# 2 languages
# /subgroups/west-13
# 8 languages
# /subgroups/pak-tong
# 1 languages
# /subgroups/southeast-islands
# 5 languages
# /subgroups/western-37
# 3 languages
# /subgroups/central-eastern-oceanic
# /subgroups/remote-oceanic
# /subgroups/central-pacific
# /subgroups/east-fijian-polynesian
# /subgroups/east-fijian
# 4 languages
# /subgroups/polynesian
# /subgroups/nuclear-1
# /subgroups/east-20
# /subgroups/central-38
# 1 languages
# /subgroups/marquesic
# 4 languages
# /subgroups/tahitic
# 7 languages
# /subgroups/rapanui
# 1 languages
# /subgroups/samoic-outlier
# /subgroups/east-uvean-niuafo%E2%80%99ou
# 2 languages
# /subgroups/ellicean
# 8 languages
# /subgroups/futunic
# 9 languages
# /subgroups/pukapuka
# 1 languages
# /subgroups/samoan
# 1 languages
# /subgroups/tokelauan
# 1 languages
# /subgroups/tongic
# 2 languages
# /subgroups/west-fijian-rotuman
# /subgroups/rotuman
# 1 languages
# /subgroups/west-fijian
# 2 languages
# /subgroups/loyalty-islands
# 3 languages
# /subgroups/micronesian
# /subgroups/micronesian-proper
# /subgroups/ikiribati
# 1 languages
# /subgroups/kusaiean
# 1 languages
# /subgroups/marshallese
# 1 languages
# /subgroups/pohnpeic-chuukic
# /subgroups/chuukic
# 13 languages
# /subgroups/pohnpeic
# 3 languages
# /subgroups/nauruan
# 1 languages
# /subgroups/new-caledonian
# /subgroups/haekic
# 1 languages
# /subgroups/northern-41
# 2 languages
# /subgroups/central-36
# 2 languages
# /subgroups/extreme-northern
# 4 languages
# /subgroups/north-13
# 2 languages
# /subgroups/hmwaveke
# 3 languages
# /subgroups/nemi
# 4 languages
# /subgroups/southern-42
# /subgroups/extreme-southern
# 2 languages
# /subgroups/south-16
# /subgroups/wailic
# 5 languages
# /subgroups/xaracuu-xaragure
# 2 languages
# /subgroups/zire-tiri
# 2 languages
# /subgroups/north-and-central-vanuatu
# /subgroups/east-santo
# /subgroups/north-14
# 1 languages
# /subgroups/south-17
# 4 languages
# /subgroups/malekula-interior
# /subgroups/labo
# 1 languages
# /subgroups/malekula-central
# 8 languages
# /subgroups/small-nambas
# 3 languages
# /subgroups/northeast-vanuatu-banks-islands
# /subgroups/central-vanuatu
# 5 languages
# /subgroups/east-vanuatu
# 32 languages
# /subgroups/epi
# /subgroups/bieria-maii
# 2 languages
# /subgroups/lamenu-baki
# /subgroups/baki-bierebo
# 2 languages
# /subgroups/lamenu-lewo
# 2 languages
# /subgroups/malekula-coastal
# 14 languages
# /subgroups/west-santo
# 24 languages
# /subgroups/south-vanuatu
# /subgroups/aneityum
# 1 languages
# /subgroups/erromanga
# 3 languages
# /subgroups/tanna
# 5 languages
# /subgroups/southeast-solomonic
# /subgroups/gela-guadalcanal
# /subgroups/bughotu
# 1 languages
# /subgroups/gela
# 2 languages
# /subgroups/guadalcanal
# 4 languages
# /subgroups/malaita-san-cristobal
# /subgroups/malaita
# /subgroups/longgu
# 1 languages
# /subgroups/northern-43
# 9 languages
# /subgroups/southern-44
# 4 languages
# /subgroups/san-cristobal
# 5 languages
# /subgroups/st-matthias
# 2 languages
# /subgroups/temotu
# /subgroups/reefs-santa-cruz
# 5 languages
# /subgroups/utupua-vanikoro
# 3 languages
# /subgroups/utupua
# 3 languages
# /subgroups/western-oceanic
# /subgroups/meso-melanesian
# /subgroups/bali-vitu
# 2 languages
# /subgroups/new-ireland
# /subgroups/lavongai-nalik
# 6 languages
# /subgroups/madak
# 3 languages
# /subgroups/south-new-ireland-northwest-solomonic
# 1 languages
# /subgroups/choiseul
# 4 languages
# /subgroups/mono-uruava
# 4 languages
# /subgroups/nehan-north-bougainville
# /subgroups/buka
# 1 languages
# /subgroups/halia
# 2 languages
# /subgroups/nehan
# 1 languages
# /subgroups/papapana
# 1 languages
# /subgroups/saposa-tinputz
# 4 languages
# /subgroups/solos
# 1 languages
# /subgroups/new-georgia
# /subgroups/east-19
# 2 languages
# /subgroups/west-15
# 11 languages
# /subgroups/patpatar-tolai
# 12 languages
# /subgroups/piva-banoni
# 2 languages
# /subgroups/santa-isabel
# /subgroups/central-37
# 3 languages
# /subgroups/east-18
# 2 languages
# /subgroups/west-16
# 2 languages
# /subgroups/tabar
# 2 languages
# /subgroups/tomoip
# 1 languages
# /subgroups/willaumez
# 4 languages
# /subgroups/north-new-guinea
# /subgroups/huon-gulf
# /subgroups/markham
# /subgroups/lower
# /subgroups/busu
# 5 languages
# /subgroups/labu
# 1 languages
# /subgroups/wampar
# 1 languages
# /subgroups/upper
# 1 languages
# /subgroups/mountain-0
# 4 languages
# /subgroups/watut
# 3 languages
# /subgroups/north-12
# 3 languages
# /subgroups/numbami
# 1 languages
# /subgroups/south-14
# /subgroups/hote-buang
# /subgroups/buang
# 5 languages
# /subgroups/mumeng
# 5 languages
# /subgroups/hote
# 2 languages
# /subgroups/kaiwa
# 1 languages
# /subgroups/ngero-vitiaz
# /subgroups/ngero
# /subgroups/bariai
# 4 languages
# /subgroups/tuam
# 2 languages
# /subgroups/vitiaz
# /subgroups/bel
# /subgroups/astrolabe
# 3 languages
# /subgroups/nuclear-bel
# /subgroups/northern-44
# 4 languages
# /subgroups/southern-45
# 1 languages
# /subgroups/kilenge-maleu
# 1 languages
# /subgroups/korap
# 4 languages
# /subgroups/mangap-mbula
# 1 languages
# /subgroups/mengen
# 3 languages
# /subgroups/roinji-nenaya
# 2 languages
# /subgroups/sio
# 1 languages
# /subgroups/southwest-new-britain
# /subgroups/amara
# 1 languages
# /subgroups/arawe-pasismanua
# /subgroups/arawe
# 1 languages
# /subgroups/east-arawe
# 4 languages
# /subgroups/west-arawe
# 4 languages
# /subgroups/pasismanua
# 5 languages
# /subgroups/bibling
# 2 languages
# /subgroups/tami
# 1 languages
# /subgroups/sarmi-jayapura-bay
# /subgroups/jayapura-bay
# 3 languages
# /subgroups/sarmi
# 11 languages
# /subgroups/schouten
# /subgroups/kairiru-manam
# /subgroups/kairiru
# 3 languages
# /subgroups/manam
# 6 languages
# /subgroups/siau
# 7 languages
# /subgroups/papuan-tip
# /subgroups/nuclear-0
# /subgroups/maisin
# 1 languages
# /subgroups/north-papuan-mainland-d%E2%80%99entrecasteaux
# /subgroups/anuki
# 1 languages
# /subgroups/are-taupota
# /subgroups/are
# 7 languages
# /subgroups/taupota
# 9 languages
# /subgroups/bwaidoga
# 7 languages
# /subgroups/dobu-duau
# 7 languages
# /subgroups/gumawana
# 1 languages
# /subgroups/kakabai
# 2 languages
# /subgroups/suauic
# 9 languages
# /subgroups/peripheral-2
# /subgroups/central-papuan
# /subgroups/oumic
# 1 languages
# /subgroups/magoric
# 3 languages
# /subgroups/sinagoro-keapara
# 4 languages
# /subgroups/west-central-papuan
# /subgroups/gabadi
# 1 languages
# /subgroups/nuclear-2
# 5 languages
# /subgroups/kilivila-louisiades
# /subgroups/kilivila
# 3 languages
# /subgroups/misima
# 1 languages
# /subgroups/nimoa-sudest
# 2 languages
# /subgroups/yapese
# 1 languages
# /subgroups/south-halmahera-west-new-guinea
# /subgroups/south-halmahera
# 1 languages
# /subgroups/east-makian-gane
# 2 languages
# /subgroups/southeast-0
# 4 languages
# /subgroups/west-new-guinea
# /subgroups/bomberai
# 2 languages
# /subgroups/cenderawasih-bay
# /subgroups/biakic
# 3 languages
# /subgroups/iresim
# 1 languages
# /subgroups/mor-0
# 1 languages
# /subgroups/raja-ampat
# 10 languages
# /subgroups/tandia
# 1 languages
# /subgroups/waropen
# 1 languages
# /subgroups/yapen-0
# /subgroups/central-western
# 11 languages
# /subgroups/east-15
# 2 languages
# /subgroups/yaur
# 1 languages
# /subgroups/yeretuar
# 1 languages
# /subgroups/hukumina
# 1 languages
# /subgroups/north-bomberai
# 4 languages
# /subgroups/south-bomberai
# 1 languages
# /subgroups/southeast-maluku
# /subgroups/kei-tanimbar
# /subgroups/kei-fordata
# 2 languages
# /subgroups/yamdena
# 1 languages
# /subgroups/southern-24
# 2 languages
# /subgroups/sumba-hawu
# /subgroups/hawu-dhao
# 2 languages
# /subgroups/sumba
# 8 languages
# /subgroups/teor-kur
# 2 languages
# /subgroups/timor-babar
# /subgroups/nuclear-timor
# 13 languages
# /subgroups/rote
# 7 languages
# /subgroups/uab-meto
# 3 languages
# /subgroups/southwest-maluku
# /subgroups/east-damar
# 1 languages
# /subgroups/kisar-roma
# 2 languages
# /subgroups/luang
# 2 languages
# /subgroups/teun-nila-serua
# /subgroups/nila-serua
# 2 languages
# /subgroups/teun
# 1 languages
# /subgroups/wetar
# 4 languages
# /subgroups/unclassified-14
# 1 languages
# /subgroups/west-damar
# 1 languages
# /subgroups/chamorro
# 1 languages
# /subgroups/greater-barito
# /subgroups/barito-mahakam
# 2 languages
# /subgroups/east-3
# /subgroups/central-south
# /subgroups/central-21
# 1 languages
# /subgroups/south-9
# 4 languages
# /subgroups/malagasy
# 12 languages
# /subgroups/north-7
# 2 languages
# /subgroups/sama-bajaw
# 1 languages
# /subgroups/abaknon
# 1 languages
# /subgroups/sulu-borneo
# /subgroups/borneo-coast-bajaw
# 3 languages
# /subgroups/inner-sulu-sama
# 3 languages
# /subgroups/western-sulu-sama
# 1 languages
# /subgroups/west-3
# /subgroups/north-6
# 3 languages
# /subgroups/south-6
# 2 languages
# /subgroups/greater-central-philippine
# /subgroups/central-philippine
# 6 languages
# /subgroups/bikol
# /subgroups/coastal-0
# /subgroups/naga
# 3 languages
# /subgroups/virac
# 1 languages
# /subgroups/inland-0
# 5 languages
# /subgroups/iriga
# 1 languages
# /subgroups/pandan
# 1 languages
# /subgroups/bisayan
# /subgroups/banton
# 1 languages
# /subgroups/cebuan
# 1 languages
# /subgroups/central-24
# 1 languages
# /subgroups/peripheral-1
# 5 languages
# /subgroups/romblon
# 1 languages
# /subgroups/warayan-0
# 3 languages
# /subgroups/gubat
# 1 languages
# /subgroups/samar-waray
# 1 languages
# /subgroups/south-10
# 2 languages
# /subgroups/butuan-tausug
# 2 languages
# /subgroups/west-8
# 1 languages
# /subgroups/aklan
# 2 languages
# /subgroups/kinarayan
# 1 languages
# /subgroups/kuyan
# 2 languages
# /subgroups/north-central-2
# 1 languages
# /subgroups/mamanwa
# 1 languages
# /subgroups/mansakan
# /subgroups/davawenyo
# 1 languages
# /subgroups/eastern-33
# 2 languages
# /subgroups/northern-32
# 1 languages
# /subgroups/western-31
# 3 languages
# /subgroups/tagalog
# 2 languages
# /subgroups/danao
# /subgroups/magindanao
# 1 languages
# /subgroups/maranao-iranon
# 3 languages
# /subgroups/gorontalo-mongondow
# /subgroups/gorontalic
# 7 languages
# /subgroups/mongondowic
# 2 languages
# /subgroups/manobo
# /subgroups/central-14
# /subgroups/east-9
# 3 languages
# /subgroups/south-11
# /subgroups/ata-tigwa
# 2 languages
# /subgroups/obo
# 1 languages
# /subgroups/west-9
# 2 languages
# /subgroups/north-8
# 4 languages
# /subgroups/south-7
# 3 languages
# /subgroups/palawanic
# 8 languages
# /subgroups/south-mangyan
# /subgroups/buhid-taubuid
# 3 languages
# /subgroups/hanunoo
# 1 languages
# /subgroups/subanon
# 1 languages
# /subgroups/eastern-26
# 5 languages
# /subgroups/umiray-dumaget
# 3 languages
# /subgroups/javanese
# 5 languages
# /subgroups/kalamian
# 2 languages
# /subgroups/lampung
# 3 languages
# /subgroups/land-dayak
# 2 languages
# /subgroups/bakati%E2%80%99
# 3 languages
# /subgroups/bidayuh
# /subgroups/core-0
# /subgroups/central-22
# 1 languages
# /subgroups/sembaan
# 1 languages
# /subgroups/western-27
# 1 languages
# /subgroups/eastern-24
# 1 languages
# /subgroups/southern-15
# 4 languages
# /subgroups/madurese
# 2 languages
# /subgroups/malayo-chamic
# /subgroups/chamic
# /subgroups/acehnese
# 1 languages
# /subgroups/coastal
# 1 languages
# /subgroups/cham
# 2 languages
# /subgroups/highlands
# 3 languages
# /subgroups/chru-northern
# 1 languages
# /subgroups/northern-cham
# 4 languages
# /subgroups/malayic
# 4 languages
# /subgroups/ibanic
# 6 languages
# /subgroups/malay
# 33 languages
# /subgroups/minahasan
# 1 languages
# /subgroups/north-3
# 1 languages
# /subgroups/northeast-0
# 3 languages
# /subgroups/moklen
# 2 languages
# /subgroups/nasal
# 1 languages
# /subgroups/north-borneo
# /subgroups/melanau-kajang
# /subgroups/kajang
# 7 languages
# /subgroups/melanau
# 5 languages
# /subgroups/north-sarawakan
# /subgroups/berawan-lower-baram
# /subgroups/berawan
# 1 languages
# /subgroups/central-east-berawan
# 2 languages
# /subgroups/lower-baram
# /subgroups/central-26
# /subgroups/a-2
# 2 languages
# /subgroups/b-2
# 3 languages
# /subgroups/bintulu
# 1 languages
# /subgroups/dayic
# /subgroups/kelabitic
# 6 languages
# /subgroups/kayan-kenyah
# /subgroups/kayanic
# /subgroups/kayan-proper
# 8 languages
# /subgroups/modang
# 2 languages
# /subgroups/muller-schwaner-%E2%80%98punan%E2%80%99
# 6 languages
# /subgroups/murik-kayan
# 1 languages
# /subgroups/kenyah
# 1 languages
# /subgroups/kayanic-kenyah
# 3 languages
# /subgroups/upper-pujungan
# 2 languages
# /subgroups/penan
# 2 languages
# /subgroups/punan-tubu
# 1 languages
# /subgroups/rejang-sajau
# 5 languages
# /subgroups/sabahan
# /subgroups/dusunic
# /subgroups/bisaya-lotud
# 2 languages
# /subgroups/southern-33
# 1 languages
# /subgroups/dusun
# 6 languages
# /subgroups/central-28
# 3 languages
# /subgroups/eastern-38
# 1 languages
# /subgroups/unclassified-24
# 1 languages
# /subgroups/ida%E2%80%99
# 1 languages
# /subgroups/murutic
# /subgroups/murut
# 6 languages
# /subgroups/northern-29
# 1 languages
# /subgroups/southern-31
# 2 languages
# /subgroups/tidung
# 3 languages
# /subgroups/unclassified-27
# 2 languages
# /subgroups/paitanic
# 2 languages
# /subgroups/upper-kinabatangan
# 3 languages
# /subgroups/unclassified-19
# 1 languages
# /subgroups/north-mangyan
# 3 languages
# /subgroups/northern-luzon
# /subgroups/arta
# 1 languages
# /subgroups/ilocano
# 1 languages
# /subgroups/meso-cordilleran
# /subgroups/alta
# 2 languages
# /subgroups/south-central-cordilleran
# /subgroups/central-cordilleran
# /subgroups/isinai
# 1 languages
# /subgroups/north-central-cordilleran
# /subgroups/kalinga-itneg
# /subgroups/itneg
# 5 languages
# /subgroups/kalinga
# 8 languages
# /subgroups/nuclear-cordilleran
# /subgroups/balangaw
# 1 languages
# /subgroups/bontok-kankanay
# /subgroups/bontok
# 5 languages
# /subgroups/kankanay
# 2 languages
# /subgroups/ifugaw
# 4 languages
# /subgroups/southern-cordilleran
# /subgroups/ilongot
# 1 languages
# /subgroups/west-southern-cordilleran
# 1 languages
# /subgroups/nuclear-southern-cordilleran
# /subgroups/ibaloy
# 2 languages
# /subgroups/kallahan
# 2 languages
# /subgroups/karaw
# 1 languages
# /subgroups/northern-cordilleran
# /subgroups/cagayan-valley
# /subgroups/ibanagic
# 6 languages
# /subgroups/gaddangic
# 3 languages
# /subgroups/isnag
# 2 languages
# /subgroups/northeastern-luzon
# 2 languages
# /subgroups/northern-31
# 4 languages
# /subgroups/northwest-sumatra-barrier-islands
# 3 languages
# /subgroups/batak
# /subgroups/northern-23
# 3 languages
# /subgroups/simalungan
# 1 languages
# /subgroups/southern-23
# 3 languages
# /subgroups/nias
# 2 languages
# /subgroups/palauan
# 1 languages
# /subgroups/rejang
# 1 languages
# /subgroups/sangiric
# /subgroups/northern-16
# 3 languages
# /subgroups/southern-14
# 2 languages
# /subgroups/south-sulawesi
# /subgroups/bugis
# 2 languages
# /subgroups/tamanic
# 2 languages
# /subgroups/lemolang
# 1 languages
# /subgroups/makassar
# 5 languages
# /subgroups/northern-15
# /subgroups/mamuju
# 1 languages
# /subgroups/mandar
# 1 languages
# /subgroups/masenrempulu
# 4 languages
# /subgroups/pitu-ulunna-salu
# 5 languages
# /subgroups/toraja-sa%E2%80%99dan
# 5 languages
# /subgroups/seko
# 2 languages
# /subgroups/panasuan
# 2 languages
# /subgroups/sundanese
# 2 languages
# /subgroups/unclassified-8
# 3 languages
# /subgroups/northwest-formosan
# 2 languages
# /subgroups/paiwan
# 1 languages
# /subgroups/puyuma
# 1 languages
# /subgroups/rukai
# 1 languages
# /subgroups/tsouic
# 3 languages
# /subgroups/unclassified-3
# 1 languages
# /subgroups/western-plains
# /subgroups/central-western-plains
# 2 languages
# /subgroups/thao
# 1 languages
# getting /subgroups/huavean
# getting /subgroups/mongolic
# /subgroups/eastern-0
# /subgroups/dagur
# 1 languages
# /subgroups/mongour
# 5 languages
# /subgroups/oirat-khalkha
# /subgroups/khalkha-buriat
# /subgroups/buriat
# 3 languages
# /subgroups/mongolian-proper
# 2 languages
# /subgroups/oirat-kalmyk-darkhat
# 1 languages
# /subgroups/western
# 1 languages
# getting /subgroups/tequistlatecan
# getting /subgroups/aymaran
# /subgroups/aymara
# 2 languages
# /subgroups/tupe
# 1 languages
# getting /subgroups/indo-european
# /subgroups/albanian
# /subgroups/gheg
# 1 languages
# /subgroups/tosk
# 3 languages
# /subgroups/armenian
# 1 languages
# /subgroups/balto-slavic
# /subgroups/baltic
# /subgroups/eastern-18
# 4 languages
# /subgroups/western-17
# 1 languages
# /subgroups/slavic
# /subgroups/east-4
# 4 languages
# /subgroups/south-3
# /subgroups/eastern-27
# 3 languages
# /subgroups/western-25
# 5 languages
# /subgroups/west-4
# /subgroups/czech-slovak
# 2 languages
# /subgroups/lechitic
# 3 languages
# /subgroups/sorbian
# 2 languages
# /subgroups/celtic
# /subgroups/insular
# /subgroups/brythonic
# 3 languages
# /subgroups/goidelic
# 3 languages
# /subgroups/germanic
# /subgroups/north
# /subgroups/east-scandinavian
# 1 languages
# /subgroups/danish-swedish
# /subgroups/danish-bokmal
# 1 languages
# /subgroups/danish-riksmal
# /subgroups/danish
# 1 languages
# /subgroups/swedish
# 1 languages
# /subgroups/west-scandinavian
# 2 languages
# /subgroups/west-0
# /subgroups/english
# 2 languages
# /subgroups/frisian
# 3 languages
# /subgroups/high-german
# /subgroups/german
# 1 languages
# /subgroups/middle-german
# /subgroups/east-middle-german
# 4 languages
# /subgroups/west-middle-german
# 3 languages
# /subgroups/moselle-franconian
# 1 languages
# /subgroups/upper-german
# 1 languages
# /subgroups/alemannic
# 4 languages
# /subgroups/bavarian-austrian
# 4 languages
# /subgroups/yiddish
# 2 languages
# /subgroups/low-saxon-low-franconian
# /subgroups/low-franconian
# 5 languages
# /subgroups/low-saxon
# 11 languages
# /subgroups/greek
# /subgroups/attic
# 5 languages
# /subgroups/doric
# 1 languages
# /subgroups/indo-iranian
# /subgroups/indo-aryan
# 1 languages
# /subgroups/intermediate-divisions
# /subgroups/eastern-28
# /subgroups/east-central
# 6 languages
# /subgroups/eastern-pahari
# 4 languages
# /subgroups/western-21
# 2 languages
# /subgroups/bhil
# 19 languages
# /subgroups/dom
# 1 languages
# /subgroups/gujarati
# 9 languages
# /subgroups/khandesi
# 3 languages
# /subgroups/pahari
# /subgroups/central-pahari
# 1 languages
# /subgroups/garhwali
# 1 languages
# /subgroups/western-pahari
# 16 languages
# /subgroups/panjabi
# 1 languages
# /subgroups/western-panjabi
# 7 languages
# /subgroups/rajasthani
# /subgroups/marwari
# 11 languages
# /subgroups/unclassified-30
# 8 languages
# /subgroups/romani
# /subgroups/balkan
# 1 languages
# /subgroups/northern-34
# 5 languages
# /subgroups/vlax
# 1 languages
# /subgroups/unclassified-22
# 5 languages
# /subgroups/outer-languages
# /subgroups/eastern-19
# /subgroups/bengali-assamese
# 19 languages
# /subgroups/bihari
# 11 languages
# /subgroups/oriya
# 9 languages
# /subgroups/unclassified-21
# 7 languages
# /subgroups/northwestern-1
# /subgroups/dardic
# /subgroups/chitral
# 2 languages
# /subgroups/kashmiri
# 1 languages
# /subgroups/kohistani
# 8 languages
# /subgroups/kunar
# 4 languages
# /subgroups/pashai
# 4 languages
# /subgroups/shina
# 8 languages
# /subgroups/sindhi
# 6 languages
# /subgroups/southern-21
# 1 languages
# /subgroups/konkani
# 7 languages
# /subgroups/sinhalese-maldivian
# 3 languages
# /subgroups/unclassified-20
# 4 languages
# /subgroups/unclassified-12
# 12 languages
# /subgroups/western-hindi
# /subgroups/bundeli
# 1 languages
# /subgroups/hindustani
# 2 languages
# /subgroups/sansi
# 2 languages
# /subgroups/unclassified-16
# 7 languages
# /subgroups/iranian
# 1 languages
# /subgroups/eastern-8
# /subgroups/northeastern
# 2 languages
# /subgroups/southeastern-0
# /subgroups/pamir
# 5 languages
# /subgroups/shugni-yazgulami
# 3 languages
# /subgroups/pashto
# 4 languages
# /subgroups/western-8
# /subgroups/northwestern-2
# 1 languages
# /subgroups/balochi
# 5 languages
# /subgroups/caspian
# 3 languages
# /subgroups/central-iran
# 12 languages
# /subgroups/kurdish
# 4 languages
# /subgroups/ormuri-parachi
# 2 languages
# /subgroups/semnani
# 4 languages
# /subgroups/talysh
# 16 languages
# /subgroups/unclassified-23
# 1 languages
# /subgroups/zaza-gorani
# 6 languages
# /subgroups/southwestern-0
# /subgroups/fars
# 2 languages
# /subgroups/luri
# 4 languages
# /subgroups/persian
# 9 languages
# /subgroups/tat
# 2 languages
# /subgroups/nuristani
# 6 languages
# /subgroups/unclassified-9
# 1 languages
# /subgroups/italic
# /subgroups/latino-faliscan
# 1 languages
# /subgroups/romance
# /subgroups/eastern-11
# 4 languages
# /subgroups/italo-western
# /subgroups/italo-dalmatian
# 5 languages
# /subgroups/western-18
# /subgroups/gallo-iberian
# /subgroups/gallo-romance
# /subgroups/gallo-italian
# 6 languages
# /subgroups/gallo-rhaetian
# /subgroups/o%C3%AFl
# /subgroups/french
# 6 languages
# /subgroups/southeastern-4
# 1 languages
# /subgroups/rhaetian
# 3 languages
# /subgroups/ibero-romance
# /subgroups/east-iberian
# 1 languages
# /subgroups/oc
# 2 languages
# /subgroups/west-iberian
# /subgroups/asturo-leonese
# 2 languages
# /subgroups/castilian
# 4 languages
# /subgroups/portuguese-galician
# 4 languages
# /subgroups/pyrenean-mozarabic
# /subgroups/pyrenean
# 1 languages
# /subgroups/southern-12
# /subgroups/corsican
# 1 languages
# /subgroups/sardinian
# 4 languages
# getting /subgroups/mosetenan
# getting /subgroups/tiniguan
# getting /subgroups/barbacoan
# /subgroups/northern-4
# 2 languages
# /subgroups/southern-4
# 2 languages
# getting /subgroups/iroquoian
# /subgroups/northern-iroquoian
# /subgroups/five-nations-huronian-susquehannock
# /subgroups/five-nations-susquehannock
# 3 languages
# /subgroups/mohawk-oneida
# 2 languages
# /subgroups/huronian
# /subgroups/huron-petun
# 1 languages
# /subgroups/tuscarora-nottoway
# 2 languages
# getting /subgroups/muran
# getting /subgroups/tor-kwerba
# /subgroups/greater-kwerba
# /subgroups/isirawa
# 1 languages
# /subgroups/kwerba
# /subgroups/nuclear
# 5 languages
# /subgroups/west-coast
# 2 languages
# /subgroups/mawes
# 1 languages
# /subgroups/orya-tor
# /subgroups/orya
# 1 languages
# /subgroups/sause
# 1 languages
# /subgroups/tor
# 13 languages
# getting /subgroups/bayono-awbono
# getting /subgroups/jabutian
# getting /subgroups/muskogean
# /subgroups/eastern-muskogean
# /subgroups/central-muskogean
# /subgroups/apalachee-alabama-koasati
# /subgroups/alabama-koasati
# 2 languages
# /subgroups/hitchiti-mikasuki
# 1 languages
# /subgroups/creek-seminole
# 1 languages
# /subgroups/western-muskogean
# 2 languages
# getting /subgroups/torricelli
# /subgroups/kombio-arapesh
# /subgroups/arapesh
# 4 languages
# /subgroups/kombio
# 6 languages
# /subgroups/maimai
# /subgroups/beli
# 1 languages
# /subgroups/laeko-libuat
# 1 languages
# /subgroups/maimai-proper
# 3 languages
# /subgroups/wiaki
# 1 languages
# /subgroups/marienberg
# 7 languages
# /subgroups/monumbo
# 2 languages
# /subgroups/urim
# 1 languages
# /subgroups/wapei-palei
# /subgroups/palei
# 10 languages
# /subgroups/urat
# 1 languages
# /subgroups/wapei
# 12 languages
# /subgroups/west-wapei
# 2 languages
# /subgroups/one
# 6 languages
# getting /subgroups/border
# /subgroups/bewani
# 5 languages
# /subgroups/taikat
# 2 languages
# /subgroups/waris
# 8 languages
# getting /subgroups/japonic
# /subgroups/ryukyuan
# /subgroups/amami-okinawan
# /subgroups/northern-amami-okinawan
# 4 languages
# /subgroups/southern-amami-okinawan
# 4 languages
# /subgroups/sakishima
# 3 languages
# getting /subgroups/nambikwara
# /subgroups/nambikwara-complex
# 1 languages
# /subgroups/northern-11
# 1 languages
# /subgroups/roosevelt-cluster
# 3 languages
# getting /subgroups/totonacan
# /subgroups/tepehua
# 3 languages
# /subgroups/totonac
# 9 languages
# getting /subgroups/bororoan
# getting /subgroups/jean
# /subgroups/central-1
# 4 languages
# /subgroups/northern-5
# 4 languages
# /subgroups/timbira
# 5 languages
# /subgroups/southern-5
# 1 languages
# /subgroups/kaingang
# 2 languages
# getting /subgroups/niger-congo
# /subgroups/atlantic-congo
# /subgroups/atlantic-0
# /subgroups/bijago
# 1 languages
# /subgroups/northern-13
# /subgroups/bak
# /subgroups/balant-ganja
# 2 languages
# /subgroups/jola
# /subgroups/bayot
# 1 languages
# /subgroups/jola-proper
# /subgroups/jola-central
# /subgroups/gusilay
# 2 languages
# /subgroups/her-ejamat
# 2 languages
# /subgroups/jola-fonyi
# 1 languages
# /subgroups/jola-kasa
# 1 languages
# /subgroups/karon-mlomp
# 2 languages
# /subgroups/kwatay
# 1 languages
# /subgroups/manjaku-papel
# 3 languages
# /subgroups/cangin
# 5 languages
# /subgroups/eastern-senegal-guinea
# /subgroups/banyun
# 3 languages
# /subgroups/nun
# 2 languages
# /subgroups/tenda
# 5 languages
# /subgroups/mbulungish-nalu
# 2 languages
# /subgroups/senegambian
# /subgroups/fula-wolof
# /subgroups/fula
# /subgroups/east-central-0
# 3 languages
# /subgroups/eastern-42
# 2 languages
# /subgroups/west-central-2
# 3 languages
# /subgroups/western-41
# 1 languages
# /subgroups/wolof
# 2 languages
# /subgroups/serer
# 1 languages
# /subgroups/southern-13
# /subgroups/limba
# 2 languages
# /subgroups/mel
# /subgroups/bullom-kissi
# /subgroups/bullom
# /subgroups/northern-37
# 2 languages
# /subgroups/southern-39
# 1 languages
# /subgroups/kissi
# 2 languages
# /subgroups/gola
# 1 languages
# /subgroups/temne
# /subgroups/baga
# 7 languages
# /subgroups/temne-banta
# 1 languages
# /subgroups/sua
# 1 languages
# /subgroups/ijoid
# /subgroups/defaka
# 1 languages
# /subgroups/ijo
# /subgroups/east-8
# 1 languages
# /subgroups/eastern-25
# /subgroups/northeastern-0
# 1 languages
# /subgroups/eastern-39
# 3 languages
# /subgroups/west-6
# /subgroups/inland-ijo
# 3 languages
# /subgroups/west-ijo
# 1 languages
# /subgroups/volta-congo
# /subgroups/benue-congo
# /subgroups/akpes
# 1 languages
# /subgroups/bantoid
# /subgroups/northern-27
# /subgroups/dakoid
# 5 languages
# /subgroups/fam
# 1 languages
# /subgroups/mambiloid
# /subgroups/mambila-konja
# /subgroups/konja
# 2 languages
# /subgroups/magu-kamkam-kila
# 4 languages
# /subgroups/mambila
# 2 languages
# /subgroups/njerup
# 1 languages
# /subgroups/ndoro
# 1 languages
# /subgroups/suga-vute
# /subgroups/suga
# 1 languages
# /subgroups/vute
# 2 languages
# /subgroups/southern-28
# /subgroups/beboid
# 9 languages
# /subgroups/ekoid
# 2 languages
# /subgroups/bakor
# 6 languages
# /subgroups/jarawan
# /subgroups/cameroon
# 2 languages
# /subgroups/nigerian
# 13 languages
# /subgroups/mamfe
# 3 languages
# /subgroups/mbe
# 1 languages
# /subgroups/narrow-bantu
# /subgroups/central-30
# /subgroups/d
# /subgroups/bembe-buyi-d54
# 1 languages
# /subgroups/bembe-buyi-d55
# 1 languages
# /subgroups/bira-nyali-d301
# 1 languages
# /subgroups/bira-nyali-d302
# 1 languages
# /subgroups/bira-nyali-d303
# 1 languages
# /subgroups/bira-nyali-d304
# 1 languages
# /subgroups/bira-nyali-d305
# 1 languages
# /subgroups/bira-nyali-d307
# 1 languages
# /subgroups/bira-nyali-d308
# 1 languages
# /subgroups/bira-nyali-d31
# 1 languages
# /subgroups/bira-nyali-d311
# 1 languages
# /subgroups/bira-nyali-d312
# 1 languages
# /subgroups/bira-nyali-d32
# 1 languages
# /subgroups/bira-nyali-d33
# 1 languages
# /subgroups/bira-nyali-d331
# 1 languages
# /subgroups/bira-nyali-d332
# 1 languages
# /subgroups/bira-nyali-d333
# 1 languages
# /subgroups/bira-nyali-d334
# 1 languages
# /subgroups/bira-nyali-d335
# 1 languages
# /subgroups/bira-nyali-d336
# 1 languages
# /subgroups/lega-holoholo-d201
# 1 languages
# /subgroups/lega-holoholo-d21
# 1 languages
# /subgroups/lega-holoholo-d211
# 1 languages
# /subgroups/lega-holoholo-d22
# 1 languages
# /subgroups/lega-holoholo-d23
# 1 languages
# /subgroups/lega-holoholo-d24
# 1 languages
# /subgroups/lega-holoholo-d25
# 1 languages
# /subgroups/lega-holoholo-d251
# 1 languages
# /subgroups/lega-holoholo-d251-0
# 2 languages
# /subgroups/lega-holoholo-d26
# 1 languages
# /subgroups/lega-holoholo-d27
# 1 languages
# /subgroups/lega-holoholo-d28
# 1 languages
# /subgroups/mbole-enya-d11
# 1 languages
# /subgroups/mbole-enya-d12
# 1 languages
# /subgroups/mbole-enya-d13
# 1 languages
# /subgroups/mbole-enya-d14
# 1 languages
# /subgroups/nyanga-d43
# 1 languages
# /subgroups/e
# /subgroups/chaga-e621
# 2 languages
# /subgroups/chaga-e622
# 2 languages
# /subgroups/chaga-e623
# 1 languages
# /subgroups/chaga-e64
# 1 languages
# /subgroups/chaga-e65
# 1 languages
# /subgroups/kikuyu-kamba-e51
# 1 languages
# /subgroups/kikuyu-kamba-e52
# 1 languages
# /subgroups/kikuyu-kamba-e53
# 1 languages
# /subgroups/kikuyu-kamba-e531
# 1 languages
# /subgroups/kikuyu-kamba-e54
# 1 languages
# /subgroups/kikuyu-kamba-e541
# 1 languages
# /subgroups/kikuyu-kamba-e55
# 1 languages
# /subgroups/kikuyu-kamba-e56
# 1 languages
# /subgroups/nyika-taita-e701
# 1 languages
# /subgroups/nyika-taita-e71
# 1 languages
# /subgroups/nyika-taita-e72
# 3 languages
# /subgroups/nyika-taita-e73
# 1 languages
# /subgroups/nyika-taita-e731
# 1 languages
# /subgroups/nyika-taita-e74
# 2 languages
# /subgroups/nyika-taita-e741
# 1 languages
# /subgroups/temi-e46
# 1 languages
# /subgroups/f
# /subgroups/nilamba-rangi-f31
# 2 languages
# /subgroups/nilamba-rangi-f32
# 1 languages
# /subgroups/nilamba-rangi-f33
# 1 languages
# /subgroups/nilamba-rangi-f34
# 1 languages
# /subgroups/sukuma-nyamwezi-f21
# 1 languages
# /subgroups/sukuma-nyamwezi-f22
# 2 languages
# /subgroups/sukuma-nyamwezi-f23
# 1 languages
# /subgroups/sukuma-nyamwezi-f24
# 1 languages
# /subgroups/sukuma-nyamwezi-f25
# 1 languages
# /subgroups/tongwe-bende-f11
# 1 languages
# /subgroups/tongwe-bende-f12
# 1 languages
# /subgroups/g
# /subgroups/bena-kinga-g61
# 1 languages
# /subgroups/bena-kinga-g62
# 1 languages
# /subgroups/bena-kinga-g63
# 1 languages
# /subgroups/bena-kinga-g64
# 1 languages
# ...
# /subgroups/trique
# 3 languages
# /subgroups/popolocan-zapotecan
# /subgroups/popolocan
# 2 languages
# /subgroups/mazatec
# 8 languages
# /subgroups/popoloca
# 7 languages
# /subgroups/zapotecan
# /subgroups/chatino
# 6 languages
# /subgroups/zapotec
# 57 languages
# /subgroups/western-otomanguean
# /subgroups/oto-pame-chinantecan
# /subgroups/chinantecan
# 14 languages
# /subgroups/oto-pamean
# 1 languages
# /subgroups/matlatzinca-ocuilteco
# 2 languages
# /subgroups/mazahua
# 2 languages
# /subgroups/otomi
# 9 languages
# /subgroups/pame
# 3 languages
# /subgroups/tlapanec-manguean
# /subgroups/manguean
# 1 languages
# /subgroups/tlapanec-subtiaba
# 1 languages
# /subgroups/tlapanec
# 4 languages
# getting /subgroups/turkic
# /subgroups/bolgar
# 1 languages
# /subgroups/eastern
# 7 languages
# /subgroups/northern-1
# 8 languages
# /subgroups/southern
# 4 languages
# /subgroups/azerbaijani
# 3 languages
# /subgroups/turkish
# 4 languages
# /subgroups/turkmenian
# 1 languages
# /subgroups/western-1
# /subgroups/aralo-caspian
# 4 languages
# /subgroups/ponto-caspian
# 4 languages
# /subgroups/uralian
# 4 languages
# getting /subgroups/chapacuran
# /subgroups/itene
# 2 languages
# /subgroups/wari
# 2 languages
# getting /subgroups/katukinan
# getting /subgroups/paezan
# /subgroups/coconuco
# 6 languages
# /subgroups/paezan-0
# 1 languages
# getting /subgroups/tuu
# /subgroups/ui
# 5 languages
# /subgroups/taa
# 1 languages
# getting /subgroups/chibchan
# /subgroups/chibchan-0
# 2 languages
# /subgroups/guaymi%C3%ADc
# 2 languages
# /subgroups/viceitic
# 2 languages
# /subgroups/chibchan-b
# 1 languages
# /subgroups/eastern-chibchan
# /subgroups/colombian
# /subgroups/northern-colombian
# 1 languages
# /subgroups/arhuacan
# 1 languages
# /subgroups/southern-and-eastern-arhuacan
# 1 languages
# /subgroups/guamaca-atanque
# 1 languages
# /subgroups/southern-colombian
# 1 languages
# /subgroups/cundicocuyese
# 4 languages
# /subgroups/cuna
# 2 languages
# /subgroups/votic
# 2 languages
# getting /subgroups/kaure
# /subgroups/kapore
# 1 languages
# /subgroups/kaure-proper
# 3 languages
# getting /subgroups/palaihnihan
# getting /subgroups/unclassified
# getting /subgroups/chimakuan
# getting /subgroups/kaweskaran
# getting /subgroups/panoan
# /subgroups/bolivian-panoan
# 1 languages
# /subgroups/ch%C3%A1kobo
# 1 languages
# /subgroups/mainline
# 2 languages
# /subgroups/cashibo
# 1 languages
# /subgroups/pano
# 1 languages
# /subgroups/shipibo
# 5 languages
# /subgroups/tri-state
# 4 languages
# /subgroups/amawaka
# 2 languages
# /subgroups/unclassified-11
# 2 languages
# /subgroups/mayoruna-mats%C3%A9s
# 2 languages
# getting /subgroups/uralic
# /subgroups/finnic
# 12 languages
# /subgroups/mari
# 2 languages
# /subgroups/mordvin
# 2 languages
# /subgroups/permian
# 1 languages
# /subgroups/komi
# 2 languages
# /subgroups/sami
# /subgroups/eastern-4
# 5 languages
# /subgroups/southern-8
# 1 languages
# /subgroups/western-6
# /subgroups/northern-17
# 3 languages
# /subgroups/southern-17
# 1 languages
# /subgroups/samoyed
# /subgroups/northern-samoyed
# 2 languages
# /subgroups/enets
# 2 languages
# /subgroups/southern-samoyed
# 2 languages
# getting /subgroups/chinookan
# /subgroups/upper-chinookan
# 1 languages
# getting /subgroups/keresan
# getting /subgroups/pauwasi
# /subgroups/eastern-1
# 3 languages
# /subgroups/western-0
# 2 languages
# getting /subgroups/uto-aztecan
# /subgroups/northern-uto-aztecan
# 2 languages
# /subgroups/numic
# /subgroups/central-8
# 3 languages
# /subgroups/southern-18
# 2 languages
# /subgroups/western-14
# 2 languages
# /subgroups/takic
# 2 languages
# /subgroups/cahuilla
# 2 languages
# /subgroups/southern-uto-aztecan
# /subgroups/corachol-aztecan
# /subgroups/cora-huichol
# 1 languages
# /subgroups/cora
# 2 languages
# /subgroups/core-nahua
# 1 languages
# /subgroups/nahuatl
# 28 languages
# /subgroups/pimic
# 3 languages
# /subgroups/tepehuan
# 3 languages
# /subgroups/taracahitic
# 1 languages
# /subgroups/cahitan
# 2 languages
# /subgroups/opatan
# 1 languages
# /subgroups/tarahumaran
# 1 languages
# /subgroups/tarahumara
# 5 languages
# getting /subgroups/chipaya-uru
# getting /subgroups/khoe-kwadi
# /subgroups/khoe
# /subgroups/kalahari-khoe
# /subgroups/north-central
# 1 languages
# /subgroups/northeast
# 2 languages
# /subgroups/northwest
# 2 languages
# /subgroups/southwest-1
# 3 languages
# /subgroups/khoekhoe
# /subgroups/hainum
# 1 languages
# /subgroups/nama
# 3 languages
# /subgroups/kwadi
# 1 languages
# getting /subgroups/piawi
# getting /subgroups/wakashan
# /subgroups/northern-wakashan
# 1 languages
# /subgroups/kwakiutlan
# 2 languages
# /subgroups/southern-wakashan
# 3 languages
# getting /subgroups/chocoan
# /subgroups/ember%C3%A1
# /subgroups/northern-ember%C3%A1
# 2 languages
# /subgroups/southern-ember%C3%A1
# 4 languages
# getting /subgroups/kiowa-tanoan
# /subgroups/tanoan
# 2 languages
# getting /subgroups/pidgin
# /subgroups/amerindian
# 2 languages
# /subgroups/assamese-based-0
# 1 languages
# /subgroups/english-based-0
# /subgroups/atlantic-1
# 1 languages
# /subgroups/pacific-0
# 1 languages
# /subgroups/french-based-0
# 1 languages
# /subgroups/hausa-based
# 2 languages
# /subgroups/iha-based
# 1 languages
# /subgroups/malay-based
# 1 languages
# /subgroups/motu-based
# 1 languages
# /subgroups/onin-based
# 1 languages
# /subgroups/romance-based
# 1 languages
# /subgroups/swahili-based-0
# 1 languages
# /subgroups/zulu-based
# 1 languages
# getting /subgroups/west-papuan
# /subgroups/north-halmahera
# /subgroups/galela-loloda
# 8 languages
# /subgroups/sahu
# 5 languages
# /subgroups/ternate-tidore
# 2 languages
# /subgroups/west-makian
# 1 languages
# /subgroups/west-bird%E2%80%99s-head
# 5 languages
# /subgroups/yapen
# 2 languages
# getting /subgroups/cholonan
# getting /subgroups/koreanic
# getting /subgroups/pomoan
# /subgroups/western-2
# 1 languages
# /subgroups/southern-9
# 3 languages
# getting /subgroups/wintuan
# getting /subgroups/chon
# /subgroups/island-chon
# 1 languages
# getting /subgroups/kwomtari
# /subgroups/guriaso
# 1 languages
# /subgroups/nuclear-kwomtari
# 2 languages
# getting /subgroups/puinavean
# /subgroups/cacua
# 2 languages
# /subgroups/hupda
# 2 languages
# /subgroups/kaburi
# 1 languages
# getting /subgroups/witotoan
# /subgroups/proto-bora-muinane
# 2 languages
# /subgroups/proto-huitoto-ocaina
# 1 languages
# /subgroups/early-huitoto
# 1 languages
# /subgroups/proto-minica-murai
# 2 languages
# getting /subgroups/chukotko-kamchatkan
# /subgroups/northern-2
# /subgroups/chukot
# 1 languages
# /subgroups/koryak-alyutor
# 3 languages
# /subgroups/southern-2
# 1 languages
# getting /subgroups/kx%E2%80%99
# /subgroups/kung
# 3 languages
# getting /subgroups/purian
# getting /subgroups/yaguan
# getting /subgroups/chumashan
# /subgroups/central-chumash
# 4 languages
# /subgroups/island-chumash
# 1 languages
# getting /subgroups/lakes-plain
# /subgroups/awera
# 1 languages
# /subgroups/east
# 2 languages
# /subgroups/rasawa-saponi
# 2 languages
# /subgroups/tariku
# /subgroups/central-5
# 2 languages
# /subgroups/duvle
# 1 languages
# /subgroups/east-2
# 9 languages
# /subgroups/west-1
# 3 languages
# getting /subgroups/quechuan
# /subgroups/central-quechua
# 1 languages
# /subgroups/ap-am-ah
# 1 languages
# /subgroups/alto-mara%C3%B1%C3%B3n
# 1 languages
# /subgroups/alto-pativilca
# 3 languages
# /subgroups/wankay
# 8 languages
# /subgroups/waylay
# 2 languages
# /subgroups/conchucos
# 4 languages
# /subgroups/peripheral-quechua
# /subgroups/chinchay
# /subgroups/northern-chinchay
# 14 languages
# /subgroups/southern-chinchay
# 3 languages
# /subgroups/southern-peruvian-quechua
# 5 languages
# /subgroups/yungay
# /subgroups/northern-19
# 2 languages
# getting /subgroups/yanomaman
# getting /subgroups/cochim%C3%AD-yuman
# /subgroups/yuman
# 2 languages
# /subgroups/delta-california
# 2 languages
# /subgroups/pai
# 2 languages
# /subgroups/river
# /subgroups/mojave
# 3 languages
# getting /subgroups/language-isolate
# getting /subgroups/ramu-lower-sepik
# /subgroups/kambot
# 1 languages
# /subgroups/lower-sepik
# /subgroups/angoram
# 1 languages
# /subgroups/chambri
# 1 languages
# /subgroups/karawari
# 2 languages
# /subgroups/nor
# 2 languages
# /subgroups/ramu
# /subgroups/grass
# 4 languages
# /subgroups/middle-ramu
# 3 languages
# /subgroups/mikarew
# 3 languages
# /subgroups/ottilien
# /subgroups/borei
# 1 languages
# /subgroups/bosmun-awar
# 2 languages
# /subgroups/watam
# 2 languages
# /subgroups/tamolan
# 6 languages
# /subgroups/tanggu
# 4 languages
# getting /subgroups/yele-west-new-britain
# /subgroups/west-new-britain
# 2 languages
# /subgroups/yele
# 1 languages
# getting /subgroups/constructed-language
# getting /subgroups/lencan
# getting /subgroups/sahaptian
# /subgroups/sahaptin
# 4 languages
# getting /subgroups/yeniseian
# getting /subgroups/coosan
# getting /subgroups/lower-mamberamo
# getting /subgroups/salish
# /subgroups/central-salish
# 8 languages
# /subgroups/lushootseed
# 4 languages
# /subgroups/interior
# 2 languages
# /subgroups/northern-10
# 1 languages
# /subgroups/southern-10
# 3 languages
# /subgroups/kalispel
# 2 languages
# /subgroups/tsamosan
# /subgroups/inland
# 2 languages
# /subgroups/maritime-0
# 2 languages
# getting /subgroups/yokutsan
# getting /subgroups/creole
# /subgroups/afrikaans-based
# 2 languages
# /subgroups/arabic-based
# 3 languages
# /subgroups/assamese-based
# 1 languages
# /subgroups/dutch-based
# 5 languages
# /subgroups/english-based
# 1 languages
# /subgroups/atlantic
# /subgroups/eastern-9
# 1 languages
# /subgroups/northern-21
# 3 languages
# /subgroups/southern-20
# 8 languages
# /subgroups/krio
# 5 languages
# /subgroups/suriname
# 1 languages
# /subgroups/ndyuka
# 2 languages
# /subgroups/western-9
# 4 languages
# /subgroups/pacific
# 8 languages
# /subgroups/french-based
# 11 languages
# /subgroups/german-based
# 1 languages
# /subgroups/hindi-based
# 1 languages
# /subgroups/iberian-based
# 1 languages
# /subgroups/kongo-based
# 2 languages
# /subgroups/malay-based-0
# 14 languages
# /subgroups/ngbandi-based
# 2 languages
# /subgroups/portuguese-based
# 13 languages
# /subgroups/spanish-based
# 2 languages
# /subgroups/swahili-based
# 1 languages
# /subgroups/tetun-based
# 1 languages
# getting /subgroups/maiduan
# /subgroups/maidu
# 2 languages
# getting /subgroups/s%C3%A1livan
# /subgroups/piaroa-maco
# 2 languages
# getting /subgroups/yuat
# getting /subgroups/dravidian
# /subgroups/central
# /subgroups/kolami-naiki
# 2 languages
# /subgroups/parji-gadaba
# 3 languages
# /subgroups/northern-0
# 6 languages
# /subgroups/south-central
# /subgroups/gondi-kui
# /subgroups/gondi
# 11 languages
# /subgroups/konda-kui
# /subgroups/konda
# 2 languages
# /subgroups/manda-kui
# /subgroups/kui-kuvi
# 3 languages
# /subgroups/manda-pengo
# 2 languages
# /subgroups/telugu
# 4 languages
# /subgroups/southern-1
# 7 languages
# /subgroups/tamil-kannada
# /subgroups/kannada
# 4 languages
# /subgroups/tamil-kodagu
# /subgroups/kodagu
# 5 languages
# /subgroups/tamil-malayalam
# 1 languages
# /subgroups/malayalam
# 9 languages
# /subgroups/tamil
# 9 languages
# /subgroups/toda-kota
# 2 languages
# /subgroups/unclassified-13
# 1 languages
# /subgroups/tulu
# 3 languages
# /subgroups/koraga
# 2 languages
# /subgroups/unclassified-7
# 4 languages
# /subgroups/unclassified-2
# 6 languages
# getting /subgroups/maipurean
# /subgroups/northern-3
# /subgroups/eastern-7
# /subgroups/palikur
# 1 languages
# /subgroups/maritime
# /subgroups/ta-maipurean
# 4 languages
# /subgroups/i%C3%B1eri
# 1 languages
# /subgroups/wapixana
# 3 languages
# /subgroups/upper-amazon
# 1 languages
# /subgroups/central-upper-amazon
# /subgroups/bar%C3%A9
# 1 languages
# /subgroups/yavitero
# 2 languages
# /subgroups/eastern-nawiki
# 1 languages
# /subgroups/karu
# 2 languages
# /subgroups/unclassified-15
# 2 languages
# /subgroups/western-nawiki
# 2 languages
# /subgroups/piapoco
# 2 languages
# /subgroups/warekena
# 2 languages
# /subgroups/southern-3
# /subgroups/campa
# 1 languages
# /subgroups/ash%C3%A9ninga
# 8 languages
# /subgroups/machiguenga
# 2 languages
# /subgroups/central-7
# /subgroups/pares%C3%AD
# 2 languages
# /subgroups/waur%C3%A1
# 1 languages
# /subgroups/waur%C3%A1-meinaku
# 2 languages
# /subgroups/southern-outlier
# /subgroups/mojo
# 2 languages
# /subgroups/mojo-0
# 2 languages
# /subgroups/piro
# 3 languages
# /subgroups/piro-0
# 3 languages
# /subgroups/terena
# 2 languages
# /subgroups/western-7
# 2 languages
# /subgroups/unclassified-4
# 2 languages
# getting /subgroups/senagi
# getting /subgroups/yukaghir
# getting /subgroups/east-bird%E2%80%99s-head-sentani
# /subgroups/burmeso
# 1 languages
# /subgroups/east-bird%E2%80%99s-head
# /subgroups/mantion
# 1 languages
# /subgroups/meax
# 2 languages
# /subgroups/sentani
# /subgroups/demta
# 1 languages
# /subgroups/sentani-proper
# 3 languages
# getting /subgroups/mairasi
# getting /subgroups/sepik
# /subgroups/abau
# 1 languages
# /subgroups/iwam
# 3 languages
# /subgroups/leonhard-schultze
# 4 languages
# /subgroups/ndu
# 13 languages
# /subgroups/nukuma
# 3 languages
# /subgroups/ram
# 3 languages
# /subgroups/sepik-hill
# /subgroups/alamblak
# 2 languages
# /subgroups/bahinemo
# 7 languages
# /subgroups/papi
# 2 languages
# /subgroups/sanio
# 5 languages
# /subgroups/tama
# 6 languages
# /subgroups/wogamusin-chenapian
# 2 languages
# /subgroups/yellow-river
# 3 languages
# /subgroups/yerakai
# 1 languages
# getting /subgroups/yukian
# /subgroups/core-yukian
# 1 languages
# getting /subgroups/east-geelvink-bay
# /subgroups/bauzi
# 2 languages
# getting /subgroups/mapudungu
# getting /subgroups/sign-language
# getting /subgroups/zamucoan
# getting /subgroups/east-new-britain
# /subgroups/baining
# 6 languages
# /subgroups/taulil
# 1 languages
# getting /subgroups/mascoyan
# /subgroups/mascoy
# 1 languages
# getting /subgroups/sino-tibetan
# /subgroups/chinese
# 14 languages
# /subgroups/tibeto-burman
# /subgroups/angami-pochuri
# 9 languages
# /subgroups/central-naga
# 4 languages
# /subgroups/central-tibeto-burman
# /subgroups/digarish
# 2 languages
# /subgroups/hrusish
# 2 languages
# /subgroups/keman
# 1 languages
# /subgroups/kho-bwa
# 6 languages
# /subgroups/lepcha
# 1 languages
# /subgroups/mijish
# 1 languages
# /subgroups/nungish
# 3 languages
# /subgroups/tani
# 7 languages
# /subgroups/karbi
# 2 languages
# /subgroups/karenic
# /subgroups/central-10
# 7 languages
# /subgroups/northern-20
# 5 languages
# /subgroups/peripheral
# 5 languages
# /subgroups/southern-19
# 4 languages
# /subgroups/kuki-chin
# 1 languages
# /subgroups/central-11
# 3 languages
# /subgroups/lai
# 4 languages
# /subgroups/mizo
# 5 languages
# /subgroups/maraic
# 3 languages
# /subgroups/mara-0
# 2 languages
# /subgroups/northwestern-0
# 9 languages
# /subgroups/peripheral-0
# /subgroups/northern-26
# 4 languages
# /subgroups/sizang
# 4 languages
# /subgroups/thado
# 3 languages
# /subgroups/southern-27
# 8 languages
# /subgroups/cho-asho
# /subgroups/asho
# 2 languages
# /subgroups/cho
# 5 languages
# /subgroups/ngwi-burmese
# /subgroups/burmish
# /subgroups/northern-24
# 6 languages
# /subgroups/southern-25
# 7 languages
# /subgroups/mru
# 2 languages
# /subgroups/ngwi
# /subgroups/central-16
# 25 languages
# /subgroups/northern-25
# 14 languages
# /subgroups/southeastern-2
# 38 languages
# /subgroups/southern-26
# 15 languages
# /subgroups/bisoid
# 4 languages
# /subgroups/unclassified-18
# 2 languages
# /subgroups/northeastern-tibeto-burman
# /subgroups/bai
# 4 languages
# /subgroups/baima
# 1 languages
# /subgroups/ersuish
# 1 languages
# /subgroups/naic
# 4 languages
# /subgroups/qiangic
# 8 languages
# /subgroups/rgyalrongic
# 4 languages
# /subgroups/tujia
# 2 languages
# /subgroups/sal
# /subgroups/boro-garo
# 4 languages
# /subgroups/boro-tiwa
# 1 languages
# /subgroups/boro
# 2 languages
# /subgroups/dimasa-kokborok
# 1 languages
# /subgroups/kok-borok
# 3 languages
# /subgroups/koch
# 4 languages
# /subgroups/northern-naga
# 13 languages
# /subgroups/dhimalish
# 2 languages
# /subgroups/jingppaw-asakia
# /subgroups/asakian
# 3 languages
# /subgroups/jingphaw
# 4 languages
# /subgroups/kuki-chin-naga
# 1 languages
# /subgroups/tangkhulic
# 4 languages
# /subgroups/unclassified-5
# 12 languages
# /subgroups/western-naga
# 7 languages
# /subgroups/western-tibeto-burman
# /subgroups/bodish
# 5 languages
# /subgroups/central-bodish
# 2 languages
# /subgroups/amdo
# 1 languages
# /subgroups/central-25
# 1 languages
# /subgroups/gtsang
# 13 languages
# /subgroups/southern-37
# 9 languages
# /subgroups/western-39
# 3 languages
# /subgroups/khams
# 1 languages
# /subgroups/unclassified-26
# 3 languages
# /subgroups/western-32
# 5 languages
# /subgroups/east-bodish
# 2 languages
# /subgroups/bumthang
# 7 languages
# /subgroups/west-bodish
# 2 languages
# /subgroups/ghale
# 3 languages
# /subgroups/gurung-tamang
# /subgroups/gurungic
# 6 languages
# /subgroups/tamang
# 4 languages
# /subgroups/west-himalayish
# /subgroups/almora
# 4 languages
# /subgroups/kinauri
# 12 languages
# /subgroups/himalayan
# /subgroups/central-himalayan
# /subgroups/chepang-bhujel
# 2 languages
# /subgroups/kham-magar
# /subgroups/kham
# 4 languages
# /subgroups/magar
# 2 languages
# /subgroups/newar
# 1 languages
# /subgroups/raute-raji
# 3 languages
# /subgroups/thangmi-baraamu
# 2 languages
# /subgroups/kiranti
# /subgroups/eastern-34
# 24 languages
# /subgroups/western-33
# 10 languages
# getting /subgroups/zaparoan
# /subgroups/iquito-cahuarano
# 2 languages
# /subgroups/z%C3%A1paro
# 1 languages
# /subgroups/arabela-andoa
# 2 languages

# %%
with gzip.open("ethnologue-tree.json.gz", "wt") as f:
    json.dump(data, f)

# %%
with gzip.open("ethnologue-tree.json.gz", "rt") as f:
    data = json.load(f)

# %%
newdata = []
def flatten_tree(node, data, parent = None, ancestors = [], family = None, depth = 0):
    out = {}
    depth += 1

    out['depth'] = depth
    out['name'] = data['name']
    out['is_language'] = data['is_language']
    try:
        out['country'] = data['country']
    except KeyError:
        pass
    try:
        out['id'] = data['id']
    except KeyError as e:
        out['id'] = node.split("/")[2]

    out['path'] = node
    out['parent'] = parent
    if parent is not None:
        out['ancestors'] = [parent] + ancestors 
    else:
        out['ancestors'] = []
    if family is None:
        out['family'] = out['path']
    else:
        out['family'] = family        
    out['children'] = [k for k in data['children'].keys()]
    out['descendants'] = []
    for k, v in data['children'].items():
        out['descendants'].append(k)
        desc = flatten_tree(k, v, 
                             parent = node,
                             ancestors = out['ancestors'],
                             depth = depth,
                             family = out['family'])
        if not (isinstance(desc, list)):
            print(type(desc))
            raise TypeError
        for d in desc:
            print(d)
            out['descendants'].append(d)
    # add this to the external dict
    newdata.append(out)
    # return descendants
    return out['descendants']
    
for k, v in data.items():
    flatten_tree(k, v)
# Out:
# /language/auj/20
# /language/swn/20
# /language/siz/20
# /subgroups/awjila-sokna
# /language/auj/20
# /language/swn/20
# /subgroups/siwa
# /language/siz/20
# /language/jbe/20
# /language/shi/20
# /language/tzm/20
# /language/zgh/20
# /language/kab/20
# /language/gha/20
# /language/jbn/20
# /language/sds/20
# /language/gho/20
# /language/oua/20
# /language/tjo/20
# /language/grr/20
# /language/mzb/20
# /language/sjs/20
# /language/rif/20
# /language/shy/20
# /language/tia/20
# /subgroups/east-7
# /language/gha/20
# /language/jbn/20
# /language/sds/20
# /subgroups/ghomara
# /language/gho/20
# /subgroups/mzab-wargla
# /language/oua/20
# /language/tjo/20
# /language/grr/20
# /language/mzb/20
# /subgroups/riff
# /language/sjs/20
# /language/rif/20
# /subgroups/shawiya
# /language/shy/20
# /subgroups/tidikelt
# /language/tia/20
# /language/cnu/20
# /subgroups/atlas
# /language/jbe/20
# /language/shi/20
# /language/tzm/20
# /language/zgh/20
# /subgroups/kabyle
# /language/kab/20
# /subgroups/zenati
# /subgroups/east-7
# /language/gha/20
# /language/jbn/20
# /language/sds/20
# /subgroups/ghomara
# /language/gho/20
# /subgroups/mzab-wargla
# /language/oua/20
# /language/tjo/20
# /language/grr/20
# /language/mzb/20
# /subgroups/riff
# /language/sjs/20
# /language/rif/20
# /subgroups/shawiya
# /language/shy/20
# /subgroups/tidikelt
# /language/tia/20
# /language/thv/20
# /language/ttq/20
# /language/thz/20
# /language/taq/20
# /subgroups/northern-12
# /language/thv/20
# /subgroups/southern-16
# /language/ttq/20
# /language/thz/20
# /language/taq/20
# /language/zen/20
# /subgroups/eastern-3
# /subgroups/awjila-sokna
# /language/auj/20
# /language/swn/20
# /subgroups/siwa
# /language/siz/20
# /subgroups/northern-6
# /language/cnu/20
# /subgroups/atlas
# /language/jbe/20
# /language/shi/20
# /language/tzm/20
# /language/zgh/20
# /subgroups/kabyle
# /language/kab/20
# /subgroups/zenati
# /subgroups/east-7
# /language/gha/20
# /language/jbn/20
# /language/sds/20
# /subgroups/ghomara
# /language/gho/20
# /subgroups/mzab-wargla
# /language/oua/20
# /language/tjo/20
# /language/grr/20
# /language/mzb/20
# /subgroups/riff
# /language/sjs/20
# /language/rif/20
# /subgroups/shawiya
# /language/shy/20
# /subgroups/tidikelt
# /language/tia/20
# /subgroups/tamasheq
# /subgroups/northern-12
# /language/thv/20
# /subgroups/southern-16
# /language/ttq/20
# /language/thz/20
# /language/taq/20
# /subgroups/zenaga
# /language/zen/20
# /language/bvw/20
# /language/gqa/20
# /language/hwo/20
# /language/jaf/20
# /language/ttr/20
# /subgroups/eastern-31
# /language/bvw/20
# /language/gqa/20
# /language/hwo/20
# /subgroups/western-30
# /language/jaf/20
# /language/ttr/20
# /language/bwr/20
# /language/ckl/20
# /language/kso/20
# /language/mfl/20
# /language/mrt/20
# /language/mfm/20
# /language/hbb/20
# /language/ngx/20
# /subgroups/1-2
# /language/bwr/20
# /language/ckl/20
# /language/kso/20
# /language/mfl/20
# /subgroups/2-2
# /language/mrt/20
# /language/mfm/20
# /language/hbb/20
# /language/bcw/20
# /language/hya/20
# /language/hig/20
# /language/fkk/20
# /language/kvj/20
# /language/xed/20
# /language/hia/20
# /language/vem/20
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /language/mfi/20
# /language/pbi/20
# /subgroups/glavda
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /subgroups/mandara
# /language/mfi/20
# /subgroups/podoko
# /language/pbi/20
# /subgroups/lamang
# /language/xed/20
# /language/hia/20
# /language/vem/20
# /subgroups/mandara-proper
# /subgroups/glavda
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /subgroups/mandara
# /language/mfi/20
# /subgroups/podoko
# /language/pbi/20
# /language/bdn/20
# /language/cuv/20
# /language/dme/20
# /language/gis/20
# /language/giz/20
# /language/mxu/20
# /language/maf/20
# /language/mfh/20
# /language/mqb/20
# /language/mfj/20
# /language/meq/20
# /language/mfk/20
# /language/mif/20
# /language/mlw/20
# /language/muy/20
# /language/mlr/20
# /language/udl/20
# /language/gnd/20
# /language/syk/20
# /language/bhs/20
# /language/dbq/20
# /language/gou/20
# /language/dkx/20
# /language/xmd/20
# /language/hna/20
# /language/bcy/20
# /language/bta/20
# /language/fli/20
# /language/gde/20
# /language/gdu/20
# /language/hod/20
# /language/jim/20
# /language/ngw/20
# /language/nja/20
# /language/swq/20
# /language/tsh/20
# /language/ziz/20
# /subgroups/a1-0
# /subgroups/eastern-31
# /language/bvw/20
# /language/gqa/20
# /language/hwo/20
# /subgroups/western-30
# /language/jaf/20
# /language/ttr/20
# /subgroups/a2-1
# /language/ngx/20
# /subgroups/1-2
# /language/bwr/20
# /language/ckl/20
# /language/kso/20
# /language/mfl/20
# /subgroups/2-2
# /language/mrt/20
# /language/mfm/20
# /language/hbb/20
# /subgroups/a3
# /language/bcw/20
# /language/hya/20
# /language/hig/20
# /language/fkk/20
# /language/kvj/20
# /subgroups/a4
# /subgroups/lamang
# /language/xed/20
# /language/hia/20
# /language/vem/20
# /subgroups/mandara-proper
# /subgroups/glavda
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /subgroups/mandara
# /language/mfi/20
# /subgroups/podoko
# /language/pbi/20
# /subgroups/a5
# /language/bdn/20
# /language/cuv/20
# /language/dme/20
# /language/gis/20
# /language/giz/20
# /language/mxu/20
# /language/maf/20
# /language/mfh/20
# /language/mqb/20
# /language/mfj/20
# /language/meq/20
# /language/mfk/20
# /language/mif/20
# /language/mlw/20
# /language/muy/20
# /language/mlr/20
# /language/udl/20
# /language/gnd/20
# /subgroups/a6
# /language/syk/20
# /subgroups/a7
# /language/bhs/20
# /language/dbq/20
# /language/gou/20
# /language/dkx/20
# /language/xmd/20
# /language/hna/20
# /subgroups/a8
# /language/bcy/20
# /language/bta/20
# /language/fli/20
# /language/gde/20
# /language/gdu/20
# /language/hod/20
# /language/jim/20
# /language/ngw/20
# /language/nja/20
# /language/swq/20
# /language/tsh/20
# /language/ziz/20
# /language/bdm/20
# /language/jia/20
# /language/xmj/20
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /language/kot/20
# /language/kqx/20
# /subgroups/north-10
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /subgroups/south-12
# /language/kot/20
# /language/kqx/20
# /language/jie/20
# /subgroups/buduma
# /language/bdm/20
# /subgroups/jina
# /language/jia/20
# /language/xmj/20
# /subgroups/kotoko-proper
# /subgroups/north-10
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /subgroups/south-12
# /language/kot/20
# /language/kqx/20
# /language/mpk/20
# /language/mug/20
# /language/mje/20
# /subgroups/b1
# /language/jie/20
# /subgroups/buduma
# /language/bdm/20
# /subgroups/jina
# /language/jia/20
# /language/xmj/20
# /subgroups/kotoko-proper
# /subgroups/north-10
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /subgroups/south-12
# /language/kot/20
# /language/kqx/20
# /subgroups/b2
# /language/mpk/20
# /language/mug/20
# /language/mje/20
# /language/gid/20
# /subgroups/a
# /subgroups/a1-0
# /subgroups/eastern-31
# /language/bvw/20
# /language/gqa/20
# /language/hwo/20
# /subgroups/western-30
# /language/jaf/20
# /language/ttr/20
# /subgroups/a2-1
# /language/ngx/20
# /subgroups/1-2
# /language/bwr/20
# /language/ckl/20
# /language/kso/20
# /language/mfl/20
# /subgroups/2-2
# /language/mrt/20
# /language/mfm/20
# /language/hbb/20
# /subgroups/a3
# /language/bcw/20
# /language/hya/20
# /language/hig/20
# /language/fkk/20
# /language/kvj/20
# /subgroups/a4
# /subgroups/lamang
# /language/xed/20
# /language/hia/20
# /language/vem/20
# /subgroups/mandara-proper
# /subgroups/glavda
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /subgroups/mandara
# /language/mfi/20
# /subgroups/podoko
# /language/pbi/20
# /subgroups/a5
# /language/bdn/20
# /language/cuv/20
# /language/dme/20
# /language/gis/20
# /language/giz/20
# /language/mxu/20
# /language/maf/20
# /language/mfh/20
# /language/mqb/20
# /language/mfj/20
# /language/meq/20
# /language/mfk/20
# /language/mif/20
# /language/mlw/20
# /language/muy/20
# /language/mlr/20
# /language/udl/20
# /language/gnd/20
# /subgroups/a6
# /language/syk/20
# /subgroups/a7
# /language/bhs/20
# /language/dbq/20
# /language/gou/20
# /language/dkx/20
# /language/xmd/20
# /language/hna/20
# /subgroups/a8
# /language/bcy/20
# /language/bta/20
# /language/fli/20
# /language/gde/20
# /language/gdu/20
# /language/hod/20
# /language/jim/20
# /language/ngw/20
# /language/nja/20
# /language/swq/20
# /language/tsh/20
# /language/ziz/20
# /subgroups/b
# /subgroups/b1
# /language/jie/20
# /subgroups/buduma
# /language/bdm/20
# /subgroups/jina
# /language/jia/20
# /language/xmj/20
# /subgroups/kotoko-proper
# /subgroups/north-10
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /subgroups/south-12
# /language/kot/20
# /language/kqx/20
# /subgroups/b2
# /language/mpk/20
# /language/mug/20
# /language/mje/20
# /subgroups/c
# /language/gid/20
# /language/mvh/20
# /language/ndm/20
# /language/sor/20
# /language/tmc/20
# /language/bvf/20
# /language/gdk/20
# /language/mlj/20
# /language/swy/20
# /language/bso/20
# /subgroups/1-1
# /language/mvh/20
# /language/ndm/20
# /language/sor/20
# /language/tmc/20
# /subgroups/2-0
# /language/bvf/20
# /language/gdk/20
# /language/mlj/20
# /language/swy/20
# /language/kqp/20
# /language/lln/20
# /language/nnc/20
# /language/gab/20
# /language/kvf/20
# /language/tng/20
# /subgroups/1-0
# /language/kqp/20
# /language/lln/20
# /language/nnc/20
# /subgroups/2-1
# /language/gab/20
# /language/kvf/20
# /language/tng/20
# /language/ker/20
# /language/kvi/20
# /subgroups/a1
# /language/bso/20
# /subgroups/1-1
# /language/mvh/20
# /language/ndm/20
# /language/sor/20
# /language/tmc/20
# /subgroups/2-0
# /language/bvf/20
# /language/gdk/20
# /language/mlj/20
# /language/swy/20
# /subgroups/a2
# /subgroups/1-0
# /language/kqp/20
# /language/lln/20
# /language/nnc/20
# /subgroups/2-1
# /language/gab/20
# /language/kvf/20
# /language/tng/20
# /subgroups/a3-0
# /language/ker/20
# /language/kvi/20
# /language/bid/20
# /language/daa/20
# /language/jeu/20
# /language/muj/20
# /language/mcw/20
# /language/mmy/20
# /language/mou/20
# /language/ubi/20
# /language/btf/20
# /language/ckq/20
# /language/mes/20
# /language/mub/20
# /language/trj/20
# /language/zrn/20
# /subgroups/1
# /language/bid/20
# /language/daa/20
# /language/jeu/20
# /language/muj/20
# /language/mcw/20
# /language/mmy/20
# /language/mou/20
# /language/ubi/20
# /subgroups/2
# /language/btf/20
# /language/ckq/20
# /language/mes/20
# /language/mub/20
# /language/trj/20
# /language/zrn/20
# /language/moz/20
# /language/bva/20
# /language/saa/20
# /language/sok/20
# /language/tax/20
# /subgroups/b1-0
# /subgroups/1
# /language/bid/20
# /language/daa/20
# /language/jeu/20
# /language/muj/20
# /language/mcw/20
# /language/mmy/20
# /language/mou/20
# /language/ubi/20
# /subgroups/2
# /language/btf/20
# /language/ckq/20
# /language/mes/20
# /language/mub/20
# /language/trj/20
# /language/zrn/20
# /subgroups/b2-0
# /language/moz/20
# /subgroups/b3
# /language/bva/20
# /language/saa/20
# /language/sok/20
# /language/tax/20
# /subgroups/a-0
# /subgroups/a1
# /language/bso/20
# /subgroups/1-1
# /language/mvh/20
# /language/ndm/20
# /language/sor/20
# /language/tmc/20
# /subgroups/2-0
# /language/bvf/20
# /language/gdk/20
# /language/mlj/20
# /language/swy/20
# /subgroups/a2
# /subgroups/1-0
# /language/kqp/20
# /language/lln/20
# /language/nnc/20
# /subgroups/2-1
# /language/gab/20
# /language/kvf/20
# /language/tng/20
# /subgroups/a3-0
# /language/ker/20
# /language/kvi/20
# /subgroups/b-0
# /subgroups/b1-0
# /subgroups/1
# /language/bid/20
# /language/daa/20
# /language/jeu/20
# /language/muj/20
# /language/mcw/20
# /language/mmy/20
# /language/mou/20
# /language/ubi/20
# /subgroups/2
# /language/btf/20
# /language/ckq/20
# /language/mes/20
# /language/mub/20
# /language/trj/20
# /language/zrn/20
# /subgroups/b2-0
# /language/moz/20
# /subgroups/b3
# /language/bva/20
# /language/saa/20
# /language/sok/20
# /language/tax/20
# /language/hed/20
# /language/mpg/20
# /language/mcn/20
# /language/zim/20
# /language/mse/20
# /language/nnn/20
# /language/lme/20
# /language/zuy/20
# /language/gwn/20
# /language/hau/20
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /language/kai/20
# /subgroups/bole-proper
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /subgroups/karekare
# /language/kai/20
# /language/kna/20
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /subgroups/dera
# /language/kna/20
# /subgroups/tangale-proper
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /subgroups/bole
# /subgroups/bole-proper
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /subgroups/karekare
# /language/kai/20
# /subgroups/tangale
# /subgroups/dera
# /language/kna/20
# /subgroups/tangale-proper
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /subgroups/1-3
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /subgroups/2-3
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /language/gek/20
# /subgroups/angas-proper
# /subgroups/1-3
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /subgroups/2-3
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /subgroups/yiwom
# /language/gek/20
# /language/fie/20
# /language/tdk/20
# /language/kbz/20
# /language/kul/20
# /language/mmf/20
# /language/cla/20
# /language/scw/20
# /subgroups/fyer
# /language/fie/20
# /language/tdk/20
# /subgroups/ron-proper
# /language/kbz/20
# /language/kul/20
# /language/mmf/20
# /language/cla/20
# /language/scw/20
# /subgroups/a1-1
# /language/gwn/20
# /language/hau/20
# /subgroups/a2-0
# /subgroups/bole
# /subgroups/bole-proper
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /subgroups/karekare
# /language/kai/20
# /subgroups/tangale
# /subgroups/dera
# /language/kna/20
# /subgroups/tangale-proper
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /subgroups/a3-1
# /subgroups/angas-proper
# /subgroups/1-3
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /subgroups/2-3
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /subgroups/yiwom
# /language/gek/20
# /subgroups/a4-0
# /subgroups/fyer
# /language/fie/20
# /language/tdk/20
# /subgroups/ron-proper
# /language/kbz/20
# /language/kul/20
# /language/mmf/20
# /language/cla/20
# /language/scw/20
# /language/bde/20
# /language/ngi/20
# /language/dbp/20
# /subgroups/bade-proper
# /language/bde/20
# /language/ngi/20
# /subgroups/duwai
# /language/dbp/20
# /language/ajw/20
# /language/tgd/20
# /language/dwa/20
# /language/kil/20
# /language/bbt/20
# /language/mkf/20
# /language/pqa/20
# /language/sir/20
# /language/wji/20
# /language/jmb/20
# /language/bux/20
# /language/kkr/20
# /language/zns/20
# /language/jmi/20
# /language/grd/20
# /language/juu/20
# /language/tak/20
# /language/zah/20
# /language/gji/20
# /language/ldd/20
# /language/plj/20
# /language/say/20
# /language/zaz/20
# /language/zua/20
# /language/dot/20
# /subgroups/boghom
# /language/bux/20
# /language/kkr/20
# /language/zns/20
# /subgroups/eastern-32
# /language/jmi/20
# /subgroups/guruntum
# /language/grd/20
# /language/juu/20
# /language/tak/20
# /language/zah/20
# /subgroups/zaar-proper
# /language/gji/20
# /language/ldd/20
# /language/plj/20
# /language/say/20
# /language/zaz/20
# /language/zua/20
# /subgroups/b1-1
# /subgroups/bade-proper
# /language/bde/20
# /language/ngi/20
# /subgroups/duwai
# /language/dbp/20
# /subgroups/b2-1
# /language/ajw/20
# /language/tgd/20
# /language/dwa/20
# /language/kil/20
# /language/bbt/20
# /language/mkf/20
# /language/pqa/20
# /language/sir/20
# /language/wji/20
# /language/jmb/20
# /subgroups/b3-0
# /language/dot/20
# /subgroups/boghom
# /language/bux/20
# /language/kkr/20
# /language/zns/20
# /subgroups/eastern-32
# /language/jmi/20
# /subgroups/guruntum
# /language/grd/20
# /language/juu/20
# /language/tak/20
# /language/zah/20
# /subgroups/zaar-proper
# /language/gji/20
# /language/ldd/20
# /language/plj/20
# /language/say/20
# /language/zaz/20
# /language/zua/20
# /subgroups/a-1
# /subgroups/a1-1
# /language/gwn/20
# /language/hau/20
# /subgroups/a2-0
# /subgroups/bole
# /subgroups/bole-proper
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /subgroups/karekare
# /language/kai/20
# /subgroups/tangale
# /subgroups/dera
# /language/kna/20
# /subgroups/tangale-proper
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /subgroups/a3-1
# /subgroups/angas-proper
# /subgroups/1-3
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /subgroups/2-3
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /subgroups/yiwom
# /language/gek/20
# /subgroups/a4-0
# /subgroups/fyer
# /language/fie/20
# /language/tdk/20
# /subgroups/ron-proper
# /language/kbz/20
# /language/kul/20
# /language/mmf/20
# /language/cla/20
# /language/scw/20
# /subgroups/b-1
# /subgroups/b1-1
# /subgroups/bade-proper
# /language/bde/20
# /language/ngi/20
# /subgroups/duwai
# /language/dbp/20
# /subgroups/b2-1
# /language/ajw/20
# /language/tgd/20
# /language/dwa/20
# /language/kil/20
# /language/bbt/20
# /language/mkf/20
# /language/pqa/20
# /language/sir/20
# /language/wji/20
# /language/jmb/20
# /subgroups/b3-0
# /language/dot/20
# /subgroups/boghom
# /language/bux/20
# /language/kkr/20
# /language/zns/20
# /subgroups/eastern-32
# /language/jmi/20
# /subgroups/guruntum
# /language/grd/20
# /language/juu/20
# /language/tak/20
# /language/zah/20
# /subgroups/zaar-proper
# /language/gji/20
# /language/ldd/20
# /language/plj/20
# /language/say/20
# /language/zaz/20
# /language/zua/20
# /subgroups/biu-mandara
# /subgroups/a
# /subgroups/a1-0
# /subgroups/eastern-31
# /language/bvw/20
# /language/gqa/20
# /language/hwo/20
# /subgroups/western-30
# /language/jaf/20
# /language/ttr/20
# /subgroups/a2-1
# /language/ngx/20
# /subgroups/1-2
# /language/bwr/20
# /language/ckl/20
# /language/kso/20
# /language/mfl/20
# /subgroups/2-2
# /language/mrt/20
# /language/mfm/20
# /language/hbb/20
# /subgroups/a3
# /language/bcw/20
# /language/hya/20
# /language/hig/20
# /language/fkk/20
# /language/kvj/20
# /subgroups/a4
# /subgroups/lamang
# /language/xed/20
# /language/hia/20
# /language/vem/20
# /subgroups/mandara-proper
# /subgroups/glavda
# /language/cie/20
# /language/dgh/20
# /language/glw/20
# /language/gdf/20
# /language/ngs/20
# /subgroups/mandara
# /language/mfi/20
# /subgroups/podoko
# /language/pbi/20
# /subgroups/a5
# /language/bdn/20
# /language/cuv/20
# /language/dme/20
# /language/gis/20
# /language/giz/20
# /language/mxu/20
# /language/maf/20
# /language/mfh/20
# /language/mqb/20
# /language/mfj/20
# /language/meq/20
# /language/mfk/20
# /language/mif/20
# /language/mlw/20
# /language/muy/20
# /language/mlr/20
# /language/udl/20
# /language/gnd/20
# /subgroups/a6
# /language/syk/20
# /subgroups/a7
# /language/bhs/20
# /language/dbq/20
# /language/gou/20
# /language/dkx/20
# /language/xmd/20
# /language/hna/20
# /subgroups/a8
# /language/bcy/20
# /language/bta/20
# /language/fli/20
# /language/gde/20
# /language/gdu/20
# /language/hod/20
# /language/jim/20
# /language/ngw/20
# /language/nja/20
# /language/swq/20
# /language/tsh/20
# /language/ziz/20
# /subgroups/b
# /subgroups/b1
# /language/jie/20
# /subgroups/buduma
# /language/bdm/20
# /subgroups/jina
# /language/jia/20
# /language/xmj/20
# /subgroups/kotoko-proper
# /subgroups/north-10
# /language/aal/20
# /language/mxf/20
# /language/msv/20
# /language/mpi/20
# /subgroups/south-12
# /language/kot/20
# /language/kqx/20
# /subgroups/b2
# /language/mpk/20
# /language/mug/20
# /language/mje/20
# /subgroups/c
# /language/gid/20
# /subgroups/east-0
# /subgroups/a-0
# /subgroups/a1
# /language/bso/20
# /subgroups/1-1
# /language/mvh/20
# /language/ndm/20
# /language/sor/20
# /language/tmc/20
# /subgroups/2-0
# /language/bvf/20
# /language/gdk/20
# /language/mlj/20
# /language/swy/20
# /subgroups/a2
# /subgroups/1-0
# /language/kqp/20
# /language/lln/20
# /language/nnc/20
# /subgroups/2-1
# /language/gab/20
# /language/kvf/20
# /language/tng/20
# /subgroups/a3-0
# /language/ker/20
# /language/kvi/20
# /subgroups/b-0
# /subgroups/b1-0
# /subgroups/1
# /language/bid/20
# /language/daa/20
# /language/jeu/20
# /language/muj/20
# /language/mcw/20
# /language/mmy/20
# /language/mou/20
# /language/ubi/20
# /subgroups/2
# /language/btf/20
# /language/ckq/20
# /language/mes/20
# /language/mub/20
# /language/trj/20
# /language/zrn/20
# /subgroups/b2-0
# /language/moz/20
# /subgroups/b3
# /language/bva/20
# /language/saa/20
# /language/sok/20
# /language/tax/20
# /subgroups/masa
# /language/hed/20
# /language/mpg/20
# /language/mcn/20
# /language/zim/20
# /language/mse/20
# /language/nnn/20
# /language/lme/20
# /language/zuy/20
# /subgroups/west-2
# /subgroups/a-1
# /subgroups/a1-1
# /language/gwn/20
# /language/hau/20
# /subgroups/a2-0
# /subgroups/bole
# /subgroups/bole-proper
# /language/bxq/20
# /language/bol/20
# /language/bvh/20
# /language/dbb/20
# /language/glo/20
# /language/gew/20
# /language/gea/20
# /language/kks/20
# /language/ktc/20
# /language/kof/20
# /language/mew/20
# /language/nbh/20
# /language/nmi/20
# /subgroups/karekare
# /language/kai/20
# /subgroups/tangale
# /subgroups/dera
# /language/kna/20
# /subgroups/tangale-proper
# /language/kuh/20
# /language/kpa/20
# /language/ksq/20
# /language/pip/20
# /language/piy/20
# /language/tan/20
# /subgroups/a3-1
# /subgroups/angas-proper
# /subgroups/1-3
# /language/cky/20
# /language/jrt/20
# /language/kwl/20
# /language/mjs/20
# /language/sur/20
# /language/anc/20
# /subgroups/2-3
# /language/ank/20
# /language/kcs/20
# /language/mtl/20
# /language/pcw/20
# /language/tal/20
# /subgroups/yiwom
# /language/gek/20
# /subgroups/a4-0
# /subgroups/fyer
# /language/fie/20
# /language/tdk/20
# /subgroups/ron-proper
# /language/kbz/20
# /language/kul/20
# /language/mmf/20
# /language/cla/20
# /language/scw/20
# /subgroups/b-1
# /subgroups/b1-1
# /subgroups/bade-proper
# /language/bde/20
# /language/ngi/20
# /subgroups/duwai
# /language/dbp/20
# /subgroups/b2-1
# /language/ajw/20
# /language/tgd/20
# /language/dwa/20
# /language/kil/20
# /language/bbt/20
# /language/mkf/20
# /language/pqa/20
# /language/sir/20
# /language/wji/20
# /language/jmb/20
# /subgroups/b3-0
# /language/dot/20
# /subgroups/boghom
# /language/bux/20
# /language/kkr/20
# /language/zns/20
# /subgroups/eastern-32
# /language/jmi/20
# /subgroups/guruntum
# /language/grd/20
# /language/juu/20
# /language/tak/20
# /language/zah/20
# /subgroups/zaar-proper
# /language/gji/20
# /language/ldd/20
# /language/plj/20
# /language/say/20
# /language/zaz/20
# /language/zua/20
# /language/xan/20
# /language/byn/20
# /language/awn/20
# /language/ahg/20
# /subgroups/eastern-12
# /language/xan/20
# /subgroups/northern-14
# /language/byn/20
# /subgroups/southern-11
# /language/awn/20
# /subgroups/western-10
# /language/ahg/20
# /language/gwd/20
# /language/tsb/20
# /language/alw/20
# /language/bji/20
# /language/drs/20
# /language/hdy/20
# /language/ktb/20
# /language/liq/20
# /language/sid/20
# /language/dox/20
# /language/gdl/20
# /language/kxc/20
# /language/orc/20
# /language/gax/20
# /language/hae/20
# /language/gaz/20
# /language/ssn/20
# /language/bob/20
# /language/rel/20
# /language/aar/20
# /language/ssy/20
# /language/dbr/20
# /language/gex/20
# /language/jii/20
# /language/ymm/20
# /language/som/20
# /language/tqq/20
# /language/arv/20
# /language/bsw/20
# /language/dsh/20
# /language/elo/20
# /language/muu/20
# /language/bnl/20
# /subgroups/dullay
# /language/gwd/20
# /language/tsb/20
# /subgroups/highland
# /language/alw/20
# /language/bji/20
# /language/drs/20
# /language/hdy/20
# /language/ktb/20
# /language/liq/20
# /language/sid/20
# /subgroups/konso-gidole
# /language/dox/20
# /language/gdl/20
# /language/kxc/20
# /subgroups/oromo
# /language/orc/20
# /language/gax/20
# /language/hae/20
# /language/gaz/20
# /language/ssn/20
# /subgroups/rendille-boni
# /language/bob/20
# /language/rel/20
# /subgroups/saho-afar
# /language/aar/20
# /language/ssy/20
# /subgroups/somali
# /language/dbr/20
# /language/gex/20
# /language/jii/20
# /language/ymm/20
# /language/som/20
# /language/tqq/20
# /subgroups/western-omo-tana
# /language/arv/20
# /language/bsw/20
# /language/dsh/20
# /language/elo/20
# /subgroups/yaaku
# /language/muu/20
# /language/bej/20
# /language/aas/20
# /language/wbj/20
# /language/bds/20
# /language/dal/20
# /language/gow/20
# /language/irk/20
# /language/wka/20
# /subgroups/central-3
# /subgroups/eastern-12
# /language/xan/20
# /subgroups/northern-14
# /language/byn/20
# /subgroups/southern-11
# /language/awn/20
# /subgroups/western-10
# /language/ahg/20
# /subgroups/east-1
# /language/bnl/20
# /subgroups/dullay
# /language/gwd/20
# /language/tsb/20
# /subgroups/highland
# /language/alw/20
# /language/bji/20
# /language/drs/20
# /language/hdy/20
# /language/ktb/20
# /language/liq/20
# /language/sid/20
# /subgroups/konso-gidole
# /language/dox/20
# /language/gdl/20
# /language/kxc/20
# /subgroups/oromo
# /language/orc/20
# /language/gax/20
# /language/hae/20
# /language/gaz/20
# /language/ssn/20
# /subgroups/rendille-boni
# /language/bob/20
# /language/rel/20
# /subgroups/saho-afar
# /language/aar/20
# /language/ssy/20
# /subgroups/somali
# /language/dbr/20
# /language/gex/20
# /language/jii/20
# /language/ymm/20
# /language/som/20
# /language/tqq/20
# /subgroups/western-omo-tana
# /language/arv/20
# /language/bsw/20
# /language/dsh/20
# /language/elo/20
# /subgroups/yaaku
# /language/muu/20
# /subgroups/north-1
# /language/bej/20
# /subgroups/south-1
# /language/aas/20
# /language/wbj/20
# /language/bds/20
# /language/dal/20
# /language/gow/20
# /language/irk/20
# /language/wka/20
# /language/cop/20
# /language/mdx/20
# /language/noz/20
# /language/she/20
# /language/jnj/20
# /language/cra/20
# /language/bcq/20
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /language/bst/20
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /subgroups/chara
# /language/cra/20
# /subgroups/gimira
# /language/bcq/20
# /subgroups/ometo
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /subgroups/janjero
# /language/jnj/20
# /subgroups/ometo-gimira
# /subgroups/chara
# /language/cra/20
# /subgroups/gimira
# /language/bcq/20
# /subgroups/ometo
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /language/myo/20
# /language/bwo/20
# /language/kbr/20
# /language/moy/20
# /subgroups/central-19
# /language/myo/20
# /subgroups/north-9
# /language/bwo/20
# /subgroups/south-8
# /language/kbr/20
# /language/moy/20
# /subgroups/gimojan
# /subgroups/janjero
# /language/jnj/20
# /subgroups/ometo-gimira
# /subgroups/chara
# /language/cra/20
# /subgroups/gimira
# /language/bcq/20
# /subgroups/ometo
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /subgroups/gonga
# /subgroups/central-19
# /language/myo/20
# /subgroups/north-9
# /language/bwo/20
# /subgroups/south-8
# /language/kbr/20
# /language/moy/20
# /language/gza/20
# /language/hoz/20
# /language/myf/20
# /language/sze/20
# /subgroups/dizoid
# /language/mdx/20
# /language/noz/20
# /language/she/20
# /subgroups/gonga-gimojan
# /subgroups/gimojan
# /subgroups/janjero
# /language/jnj/20
# /subgroups/ometo-gimira
# /subgroups/chara
# /language/cra/20
# /subgroups/gimira
# /language/bcq/20
# /subgroups/ometo
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /subgroups/gonga
# /subgroups/central-19
# /language/myo/20
# /subgroups/north-9
# /language/bwo/20
# /subgroups/south-8
# /language/kbr/20
# /language/moy/20
# /subgroups/mao
# /language/gza/20
# /language/hoz/20
# /language/myf/20
# /language/sze/20
# /language/aiw/20
# /language/dim/20
# /language/gyl/20
# /language/amf/20
# /language/kxh/20
# /subgroups/north-0
# /subgroups/dizoid
# /language/mdx/20
# /language/noz/20
# /language/she/20
# /subgroups/gonga-gimojan
# /subgroups/gimojan
# /subgroups/janjero
# /language/jnj/20
# /subgroups/ometo-gimira
# /subgroups/chara
# /language/cra/20
# /subgroups/gimira
# /language/bcq/20
# /subgroups/ometo
# /language/mdy/20
# /subgroups/central-34
# /language/dwr/20
# /language/doz/20
# /language/gmv/20
# /language/gof/20
# /language/mfx/20
# /language/oyd/20
# /language/wal/20
# /subgroups/east-12
# /language/kcx/20
# /language/kqy/20
# /language/zay/20
# /subgroups/west-10
# /language/bst/20
# /subgroups/gonga
# /subgroups/central-19
# /language/myo/20
# /subgroups/north-9
# /language/bwo/20
# /subgroups/south-8
# /language/kbr/20
# /language/moy/20
# /subgroups/mao
# /language/gza/20
# /language/hoz/20
# /language/myf/20
# /language/sze/20
# /subgroups/south-0
# /language/aiw/20
# /language/dim/20
# /language/gyl/20
# /language/amf/20
# /language/kxh/20
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /language/lhs/20
# /language/tru/20
# /subgroups/northeastern-1
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /subgroups/northwestern-5
# /language/lhs/20
# /language/tru/20
# /language/mid/20
# /language/myz/20
# /language/syc/20
# /subgroups/central-20
# /subgroups/northeastern-1
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /subgroups/northwestern-5
# /language/lhs/20
# /language/tru/20
# /subgroups/mandaic
# /language/mid/20
# /language/myz/20
# /language/sam/20
# /language/amw/20
# /subgroups/eastern-22
# /language/syc/20
# /subgroups/central-20
# /subgroups/northeastern-1
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /subgroups/northwestern-5
# /language/lhs/20
# /language/tru/20
# /subgroups/mandaic
# /language/mid/20
# /language/myz/20
# /subgroups/western-23
# /language/sam/20
# /language/amw/20
# /language/aao/20
# /language/arq/20
# /language/abv/20
# /language/shu/20
# /language/acy/20
# /language/adf/20
# /language/avl/20
# /language/arz/20
# /language/afb/20
# /language/ayh/20
# /language/acw/20
# /language/yhd/20
# /language/aju/20
# /language/yud/20
# /language/ajt/20
# /language/jye/20
# /language/ayl/20
# /language/acm/20
# /language/ary/20
# /language/ars/20
# /language/apc/20
# /language/ayp/20
# /language/acx/20
# /language/ayn/20
# /language/aec/20
# /language/ssh/20
# /language/ajp/20
# /language/arb/20
# /language/apd/20
# /language/abh/20
# /language/acq/20
# /language/aeb/20
# /language/auz/20
# /language/mey/20
# /language/mlt/20
# /language/heb/20
# /language/hbo/20
# /language/smp/20
# /subgroups/arabic
# /language/aao/20
# /language/arq/20
# /language/abv/20
# /language/shu/20
# /language/acy/20
# /language/adf/20
# /language/avl/20
# /language/arz/20
# /language/afb/20
# /language/ayh/20
# /language/acw/20
# /language/yhd/20
# /language/aju/20
# /language/yud/20
# /language/ajt/20
# /language/jye/20
# /language/ayl/20
# /language/acm/20
# /language/ary/20
# /language/ars/20
# /language/apc/20
# /language/ayp/20
# /language/acx/20
# /language/ayn/20
# /language/aec/20
# /language/ssh/20
# /language/ajp/20
# /language/arb/20
# /language/apd/20
# /language/abh/20
# /language/acq/20
# /language/aeb/20
# /language/auz/20
# /language/mey/20
# /language/mlt/20
# /subgroups/canaanite
# /language/heb/20
# /language/hbo/20
# /language/smp/20
# /language/rzh/20
# /subgroups/aramaic
# /subgroups/eastern-22
# /language/syc/20
# /subgroups/central-20
# /subgroups/northeastern-1
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /subgroups/northwestern-5
# /language/lhs/20
# /language/tru/20
# /subgroups/mandaic
# /language/mid/20
# /language/myz/20
# /subgroups/western-23
# /language/sam/20
# /language/amw/20
# /subgroups/south-2
# /subgroups/arabic
# /language/aao/20
# /language/arq/20
# /language/abv/20
# /language/shu/20
# /language/acy/20
# /language/adf/20
# /language/avl/20
# /language/arz/20
# /language/afb/20
# /language/ayh/20
# /language/acw/20
# /language/yhd/20
# /language/aju/20
# /language/yud/20
# /language/ajt/20
# /language/jye/20
# /language/ayl/20
# /language/acm/20
# /language/ary/20
# /language/ars/20
# /language/apc/20
# /language/ayp/20
# /language/acx/20
# /language/ayn/20
# /language/aec/20
# /language/ssh/20
# /language/ajp/20
# /language/arb/20
# /language/apd/20
# /language/abh/20
# /language/acq/20
# /language/aeb/20
# /language/auz/20
# /language/mey/20
# /language/mlt/20
# /subgroups/canaanite
# /language/heb/20
# /language/hbo/20
# /language/smp/20
# /language/dlk/20
# /language/gez/20
# /language/tig/20
# /language/tir/20
# /language/gru/20
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /subgroups/n-group
# /language/gru/20
# /subgroups/tt-group
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /language/amh/20
# /language/agj/20
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /subgroups/amharic-argobba
# /language/amh/20
# /language/agj/20
# /subgroups/harari-east-gurage
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /subgroups/outer
# /subgroups/n-group
# /language/gru/20
# /subgroups/tt-group
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /subgroups/transversal
# /subgroups/amharic-argobba
# /language/amh/20
# /language/agj/20
# /subgroups/harari-east-gurage
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /subgroups/north-4
# /language/dlk/20
# /language/gez/20
# /language/tig/20
# /language/tir/20
# /subgroups/south-4
# /subgroups/outer
# /subgroups/n-group
# /language/gru/20
# /subgroups/tt-group
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /subgroups/transversal
# /subgroups/amharic-argobba
# /language/amh/20
# /language/agj/20
# /subgroups/harari-east-gurage
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /language/bhm/20
# /language/hss/20
# /language/hoh/20
# /language/gdq/20
# /language/shv/20
# /language/sqt/20
# /subgroups/ethiopian
# /subgroups/north-4
# /language/dlk/20
# /language/gez/20
# /language/tig/20
# /language/tir/20
# /subgroups/south-4
# /subgroups/outer
# /subgroups/n-group
# /language/gru/20
# /subgroups/tt-group
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /subgroups/transversal
# /subgroups/amharic-argobba
# /language/amh/20
# /language/agj/20
# /subgroups/harari-east-gurage
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /subgroups/south-arabian
# /language/bhm/20
# /language/hss/20
# /language/hoh/20
# /language/gdq/20
# /language/shv/20
# /language/sqt/20
# /subgroups/central-2
# /language/rzh/20
# /subgroups/aramaic
# /subgroups/eastern-22
# /language/syc/20
# /subgroups/central-20
# /subgroups/northeastern-1
# /language/aii/20
# /language/bjf/20
# /language/bhn/20
# /language/cld/20
# /language/hrt/20
# /language/huy/20
# /language/tmr/20
# /language/kqd/20
# /language/trg/20
# /language/lsd/20
# /language/aij/20
# /language/syn/20
# /subgroups/northwestern-5
# /language/lhs/20
# /language/tru/20
# /subgroups/mandaic
# /language/mid/20
# /language/myz/20
# /subgroups/western-23
# /language/sam/20
# /language/amw/20
# /subgroups/south-2
# /subgroups/arabic
# /language/aao/20
# /language/arq/20
# /language/abv/20
# /language/shu/20
# /language/acy/20
# /language/adf/20
# /language/avl/20
# /language/arz/20
# /language/afb/20
# /language/ayh/20
# /language/acw/20
# /language/yhd/20
# /language/aju/20
# /language/yud/20
# /language/ajt/20
# /language/jye/20
# /language/ayl/20
# /language/acm/20
# /language/ary/20
# /language/ars/20
# /language/apc/20
# /language/ayp/20
# /language/acx/20
# /language/ayn/20
# /language/aec/20
# /language/ssh/20
# /language/ajp/20
# /language/arb/20
# /language/apd/20
# /language/abh/20
# /language/acq/20
# /language/aeb/20
# /language/auz/20
# /language/mey/20
# /language/mlt/20
# /subgroups/canaanite
# /language/heb/20
# /language/hbo/20
# /language/smp/20
# /subgroups/south
# /subgroups/ethiopian
# /subgroups/north-4
# /language/dlk/20
# /language/gez/20
# /language/tig/20
# /language/tir/20
# /subgroups/south-4
# /subgroups/outer
# /subgroups/n-group
# /language/gru/20
# /subgroups/tt-group
# /language/ior/20
# /language/mys/20
# /language/mvz/20
# /language/sgw/20
# /subgroups/transversal
# /subgroups/amharic-argobba
# /language/amh/20
# /language/agj/20
# /subgroups/harari-east-gurage
# /language/har/20
# /language/stv/20
# /language/wle/20
# /language/zwa/20
# /subgroups/south-arabian
# /language/bhm/20
# /language/hss/20
# /language/hoh/20
# /language/gdq/20
# /language/shv/20
# /language/sqt/20
# /language/bxe/20
# /language/crt/20
# /language/crq/20
# /language/mzh/20
# /language/mtp/20
# /language/wlv/20
# /language/chc/20
# /language/win/20
# /language/iow/20
# /language/asb/20
# /language/dak/20
# /language/lkt/20
# /language/sto/20
# /language/ksk/20
# /language/oma/20
# /language/osa/20
# /language/qua/20
# /subgroups/chiwere-winnebago
# /language/win/20
# /language/iow/20
# /subgroups/dakota
# /language/asb/20
# /language/dak/20
# /language/lkt/20
# /language/sto/20
# /subgroups/dhegihan
# /language/ksk/20
# /language/oma/20
# /language/osa/20
# /language/qua/20
# /subgroups/mississippi-valley-siouan
# /subgroups/chiwere-winnebago
# /language/win/20
# /language/iow/20
# /subgroups/dakota
# /language/asb/20
# /language/dak/20
# /language/lkt/20
# /language/sto/20
# /subgroups/dhegihan
# /language/ksk/20
# /language/oma/20
# /language/osa/20
# /language/qua/20
# /language/cro/20
# /language/hid/20
# /language/mhq/20
# /subgroups/mississippi-valley-ohio-valley-siouan
# /subgroups/mississippi-valley-siouan
# /subgroups/chiwere-winnebago
# /language/win/20
# /language/iow/20
# /subgroups/dakota
# /language/asb/20
# /language/dak/20
# /language/lkt/20
# /language/sto/20
# /subgroups/dhegihan
# /language/ksk/20
# /language/oma/20
# /language/osa/20
# /language/qua/20
# /subgroups/missouri-river-siouan
# /language/cro/20
# /language/hid/20
# /language/arp/20
# /language/ats/20
# /language/atj/20
# /language/crm/20
# /language/crl/20
# /language/crk/20
# /language/crj/20
# /language/csw/20
# /language/cwd/20
# /language/moe/20
# /language/nsk/20
# /language/aaq/20
# /language/abe/20
# /language/umu/20
# /language/unm/20
# /language/nnt/20
# /language/psy/20
# /language/pqm/20
# /language/mic/20
# /language/xpq/20
# /language/xnt/20
# /language/pim/20
# /language/wam/20
# /subgroups/abenaki
# /language/aaq/20
# /language/abe/20
# /subgroups/delaware
# /language/umu/20
# /language/unm/20
# /subgroups/nanticoke-conoy
# /language/nnt/20
# /language/psy/20
# /language/kic/20
# /language/sac/20
# /language/alq/20
# /language/ciw/20
# /language/ojc/20
# /language/ojg/20
# /language/ojb/20
# /language/ojs/20
# /language/ojw/20
# /language/otw/20
# /language/pot/20
# /language/lmz/20
# /language/bla/20
# /language/chy/20
# /language/mez/20
# /language/mia/20
# /language/sjw/20
# /subgroups/arapaho
# /language/arp/20
# /language/ats/20
# /subgroups/cree-montagnais
# /language/atj/20
# /language/crm/20
# /language/crl/20
# /language/crk/20
# /language/crj/20
# /language/csw/20
# /language/cwd/20
# /language/moe/20
# /language/nsk/20
# /subgroups/eastern-algonquian
# /language/pqm/20
# /language/mic/20
# /language/xpq/20
# /language/xnt/20
# /language/pim/20
# /language/wam/20
# /subgroups/abenaki
# /language/aaq/20
# /language/abe/20
# /subgroups/delaware
# /language/umu/20
# /language/unm/20
# /subgroups/nanticoke-conoy
# /language/nnt/20
# /language/psy/20
# /subgroups/fox
# /language/kic/20
# /language/sac/20
# /subgroups/ojibwa-potawatomi
# /language/alq/20
# /language/ciw/20
# /language/ojc/20
# /language/ojg/20
# /language/ojb/20
# /language/ojs/20
# /language/ojw/20
# /language/otw/20
# /language/pot/20
# /subgroups/unclassified-10
# /language/lmz/20
# /language/wiy/20
# /language/yur/20
# /language/ale/20
# /language/kal/20
# /language/ikt/20
# /language/ike/20
# /language/esi/20
# /language/esk/20
# /language/esu/20
# /language/ems/20
# /language/ess/20
# /language/ynk/20
# /language/ysr/20
# /subgroups/alaskan-yupik
# /language/esu/20
# /language/ems/20
# /subgroups/inuit-inupiaq
# /language/kal/20
# /language/ikt/20
# /language/ike/20
# /language/esi/20
# /language/esk/20
# /subgroups/yupik
# /language/ess/20
# /language/ynk/20
# /language/ysr/20
# /subgroups/alaskan-yupik
# /language/esu/20
# /language/ems/20
# /language/ksi/20
# /language/vam/20
# /language/wut/20
# /language/skv/20
# /subgroups/eastern-skou
# /language/vam/20
# /language/wut/20
# /subgroups/skou-0
# /language/skv/20
# /language/wra/20
# /language/pux/20
# /language/wmx/20
# /language/rwa/20
# /subgroups/main-serra
# /language/wmx/20
# /subgroups/rawo
# /language/rwa/20
# /subgroups/piore-river
# /language/wra/20
# /subgroups/puari
# /language/pux/20
# /subgroups/rawo-main-serra
# /subgroups/main-serra
# /language/wmx/20
# /subgroups/rawo
# /language/rwa/20
# /subgroups/nuclear-skou
# /subgroups/eastern-skou
# /language/vam/20
# /language/wut/20
# /subgroups/skou-0
# /language/skv/20
# /subgroups/serra-hills
# /subgroups/piore-river
# /language/wra/20
# /subgroups/puari
# /language/pux/20
# /subgroups/rawo-main-serra
# /subgroups/main-serra
# /language/wmx/20
# /subgroups/rawo
# /language/rwa/20
# /language/apj/20
# /language/apk/20
# /language/apl/20
# /language/apm/20
# /language/apw/20
# /language/nav/20
# /subgroups/apache
# /language/apj/20
# /language/apk/20
# /language/apl/20
# /language/apm/20
# /language/apw/20
# /language/crx/20
# /language/caf/20
# /language/scs/20
# /language/xsl/20
# /language/kkz/20
# /language/tgx/20
# /language/tht/20
# /language/ttm/20
# /language/tce/20
# /language/aht/20
# /language/bcr/20
# /language/bea/20
# /language/clc/20
# /language/ing/20
# /language/chp/20
# /language/dgr/20
# /language/gwi/20
# /language/haa/20
# /language/hoi/20
# /language/koy/20
# /language/kuu/20
# /language/srs/20
# /language/sek/20
# /language/tcb/20
# /language/tfn/20
# /language/taa/20
# /language/tau/20
# /subgroups/carrier
# /language/crx/20
# /language/caf/20
# /subgroups/slavey-hare
# /language/scs/20
# /language/xsl/20
# /subgroups/tahltan
# /language/kkz/20
# /language/tgx/20
# /language/tht/20
# /subgroups/tuchone
# /language/ttm/20
# /language/tce/20
# /language/hup/20
# /language/ktw/20
# /language/mvb/20
# /language/wlk/20
# /language/ctc/20
# /language/tol/20
# /language/coq/20
# /language/tuu/20
# /language/gce/20
# /subgroups/tolowa-chetco
# /language/ctc/20
# /language/tol/20
# /subgroups/tututni-chasta-costa-coquille
# /language/coq/20
# /language/tuu/20
# /subgroups/california-athabaskan
# /language/hup/20
# /language/ktw/20
# /language/mvb/20
# /language/wlk/20
# /subgroups/oregon-athabaskan
# /language/gce/20
# /subgroups/tolowa-chetco
# /language/ctc/20
# /language/tol/20
# /subgroups/tututni-chasta-costa-coquille
# /language/coq/20
# /language/tuu/20
# /subgroups/apachean
# /language/nav/20
# /subgroups/apache
# /language/apj/20
# /language/apk/20
# /language/apl/20
# /language/apm/20
# /language/apw/20
# /subgroups/northern-athabaskan
# /language/aht/20
# /language/bcr/20
# /language/bea/20
# /language/clc/20
# /language/ing/20
# /language/chp/20
# /language/dgr/20
# /language/gwi/20
# /language/haa/20
# /language/hoi/20
# /language/koy/20
# /language/kuu/20
# /language/srs/20
# /language/sek/20
# /language/tcb/20
# /language/tfn/20
# /language/taa/20
# /language/tau/20
# /subgroups/carrier
# /language/crx/20
# /language/caf/20
# /subgroups/slavey-hare
# /language/scs/20
# /language/xsl/20
# /subgroups/tahltan
# /language/kkz/20
# /language/tgx/20
# /language/tht/20
# /subgroups/tuchone
# /language/ttm/20
# /language/tce/20
# /subgroups/pacific-coast-athabaskan
# /subgroups/california-athabaskan
# /language/hup/20
# /language/ktw/20
# /language/mvb/20
# /language/wlk/20
# /subgroups/oregon-athabaskan
# /language/gce/20
# /subgroups/tolowa-chetco
# /language/ctc/20
# /language/tol/20
# /subgroups/tututni-chasta-costa-coquille
# /language/coq/20
# /language/tuu/20
# /language/tli/20
# /language/hus/20
# /language/cob/20
# /subgroups/huastec
# /language/hus/20
# /language/ctu/20
# /language/chf/20
# /subgroups/chol
# /language/ctu/20
# /language/caa/20
# /subgroups/chol-chontal
# /language/chf/20
# /subgroups/chol
# /language/ctu/20
# /subgroups/chorti-cholti
# /language/caa/20
# /language/tzh/20
# /language/tzo/20
# /subgroups/tzeltal
# /language/tzh/20
# /subgroups/tzotzil
# /language/tzo/20
# /subgroups/cholan
# /subgroups/chol-chontal
# /language/chf/20
# /subgroups/chol
# /language/ctu/20
# /subgroups/chorti-cholti
# /language/caa/20
# /subgroups/tzeltalan
# /subgroups/tzeltal
# /language/tzh/20
# /subgroups/tzotzil
# /language/tzo/20
# /subgroups/cholan-tzeltalan
# /subgroups/cholan
# /subgroups/chol-chontal
# /language/chf/20
# /subgroups/chol
# /language/ctu/20
# /subgroups/chorti-cholti
# /language/caa/20
# /subgroups/tzeltalan
# /subgroups/tzeltal
# /language/tzh/20
# /subgroups/tzotzil
# /language/tzo/20
# /language/cak/20
# /language/tzj/20
# /language/acr/20
# /language/quc/20
# /language/quv/20
# /language/qum/20
# /subgroups/kaqchikel-tz%E2%80%99utujil
# /language/cak/20
# /language/tzj/20
# /language/poc/20
# /language/poh/20
# /subgroups/poqomam
# /language/poc/20
# /subgroups/poqomchi%E2%80%99
# /language/poh/20
# /subgroups/core-k%E2%80%99ichean
# /language/acr/20
# /language/quc/20
# /language/quv/20
# /language/qum/20
# /subgroups/kaqchikel-tz%E2%80%99utujil
# /language/cak/20
# /language/tzj/20
# /subgroups/poqom
# /subgroups/poqomam
# /language/poc/20
# /subgroups/poqomchi%E2%80%99
# /language/poh/20
# /language/kek/20
# /language/usp/20
# /subgroups/poqom-k%E2%80%99ichean
# /subgroups/core-k%E2%80%99ichean
# /language/acr/20
# /language/quc/20
# /language/quv/20
# /language/qum/20
# /subgroups/kaqchikel-tz%E2%80%99utujil
# /language/cak/20
# /language/tzj/20
# /subgroups/poqom
# /subgroups/poqomam
# /language/poc/20
# /subgroups/poqomchi%E2%80%99
# /language/poh/20
# /language/agu/20
# /language/ixl/20
# /language/mam/20
# /language/ttc/20
# /subgroups/awakateko-ixil
# /language/agu/20
# /language/ixl/20
# /subgroups/teco-mam
# /language/mam/20
# /language/ttc/20
# /subgroups/k%E2%80%99ichean
# /language/kek/20
# /language/usp/20
# /subgroups/poqom-k%E2%80%99ichean
# /subgroups/core-k%E2%80%99ichean
# /language/acr/20
# /language/quc/20
# /language/quv/20
# /language/qum/20
# /subgroups/kaqchikel-tz%E2%80%99utujil
# /language/cak/20
# /language/tzj/20
# /subgroups/poqom
# /subgroups/poqomam
# /language/poc/20
# /subgroups/poqomchi%E2%80%99
# /language/poh/20
# /subgroups/mamean
# /subgroups/awakateko-ixil
# /language/agu/20
# /language/ixl/20
# /subgroups/teco-mam
# /language/mam/20
# /language/ttc/20
# /language/cac/20
# /language/toj/20
# /language/knj/20
# /language/jac/20
# /language/kjb/20
# /language/mhc/20
# /subgroups/q%E2%80%99anjob%E2%80%99al-akateko-jakalteko
# /language/knj/20
# /language/jac/20
# /language/kjb/20
# /subgroups/chujean
# /language/cac/20
# /language/toj/20
# /subgroups/q%E2%80%99anjob%E2%80%99alan
# /language/mhc/20
# /subgroups/q%E2%80%99anjob%E2%80%99al-akateko-jakalteko
# /language/knj/20
# /language/jac/20
# /language/kjb/20
# /language/itz/20
# /language/mop/20
# /language/lac/20
# /language/yua/20
# /subgroups/mopan-itz%C3%A1
# /language/itz/20
# /language/mop/20
# /subgroups/yucatec-lacandon
# /language/lac/20
# /language/yua/20
# /subgroups/core-mayan
# /subgroups/cholan-tzeltalan
# /subgroups/cholan
# /subgroups/chol-chontal
# /language/chf/20
# /subgroups/chol
# /language/ctu/20
# /subgroups/chorti-cholti
# /language/caa/20
# /subgroups/tzeltalan
# /subgroups/tzeltal
# /language/tzh/20
# /subgroups/tzotzil
# /language/tzo/20
# /subgroups/k%E2%80%99ichean-mamean
# /subgroups/k%E2%80%99ichean
# /language/kek/20
# /language/usp/20
# /subgroups/poqom-k%E2%80%99ichean
# /subgroups/core-k%E2%80%99ichean
# /language/acr/20
# /language/quc/20
# /language/quv/20
# /language/qum/20
# /subgroups/kaqchikel-tz%E2%80%99utujil
# /language/cak/20
# /language/tzj/20
# /subgroups/poqom
# /subgroups/poqomam
# /language/poc/20
# /subgroups/poqomchi%E2%80%99
# /language/poh/20
# /subgroups/mamean
# /subgroups/awakateko-ixil
# /language/agu/20
# /language/ixl/20
# /subgroups/teco-mam
# /language/mam/20
# /language/ttc/20
# /subgroups/q%E2%80%99anjob%E2%80%99alan-chujean
# /subgroups/chujean
# /language/cac/20
# /language/toj/20
# /subgroups/q%E2%80%99anjob%E2%80%99alan
# /language/mhc/20
# /subgroups/q%E2%80%99anjob%E2%80%99al-akateko-jakalteko
# /language/knj/20
# /language/jac/20
# /language/kjb/20
# /subgroups/yucatecan
# /subgroups/mopan-itz%C3%A1
# /language/itz/20
# /language/mop/20
# /subgroups/yucatec-lacandon
# /language/lac/20
# /language/yua/20
# /language/apq/20
# /language/abj/20
# /language/akx/20
# /language/aky/20
# /language/acl/20
# /language/okj/20
# /language/akm/20
# /language/aci/20
# /language/akj/20
# /language/ack/20
# /language/gac/20
# /subgroups/central-4
# /language/apq/20
# /language/abj/20
# /language/akx/20
# /language/aky/20
# /language/acl/20
# /language/okj/20
# /subgroups/northern-7
# /language/akm/20
# /language/aci/20
# /language/akj/20
# /language/ack/20
# /language/anq/20
# /language/oon/20
# /language/std/20
# ...
# /language/bee/20
# /language/cdn/20
# /language/drd/20
# /language/rgk/20
# /subgroups/kinauri
# /language/bfu/20
# /language/jna/20
# /language/xns/20
# /language/kfk/20
# /language/nes/20
# /language/cik/20
# /language/lae/20
# /language/rnp/20
# /language/scu/20
# /language/ssk/20
# /language/lbf/20
# /language/tpq/20
# /language/byh/20
# /language/cdm/20
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /language/mgp/20
# /language/mrd/20
# /subgroups/kham
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /subgroups/magar
# /language/mgp/20
# /language/mrd/20
# /language/new/20
# /language/rji/20
# /language/rau/20
# /language/jnl/20
# /language/brd/20
# /language/thf/20
# /subgroups/chepang-bhujel
# /language/byh/20
# /language/cdm/20
# /subgroups/kham-magar
# /subgroups/kham
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /subgroups/magar
# /language/mgp/20
# /language/mrd/20
# /subgroups/newar
# /language/new/20
# /subgroups/raute-raji
# /language/rji/20
# /language/rau/20
# /language/jnl/20
# /subgroups/thangmi-baraamu
# /language/brd/20
# /language/thf/20
# /language/aph/20
# /language/bap/20
# /language/byw/20
# /language/rab/20
# /language/ctn/20
# /language/cur/20
# /language/cuw/20
# /language/raa/20
# /language/kle/20
# /language/lif/20
# /language/lbr/20
# /language/emg/20
# /language/raf/20
# /language/lmh/20
# /language/ncd/20
# /language/phw/20
# /language/pum/20
# /language/raq/20
# /language/rav/20
# /language/wly/20
# /language/ybh/20
# /language/luu/20
# /language/ybi/20
# /language/lrr/20
# /language/bhj/20
# /language/dus/20
# /language/jee/20
# /language/klr/20
# /language/kkt/20
# /language/suz/20
# /language/tdh/20
# /language/tij/20
# /language/wme/20
# /language/vay/20
# /subgroups/eastern-34
# /language/aph/20
# /language/bap/20
# /language/byw/20
# /language/rab/20
# /language/ctn/20
# /language/cur/20
# /language/cuw/20
# /language/raa/20
# /language/kle/20
# /language/lif/20
# /language/lbr/20
# /language/emg/20
# /language/raf/20
# /language/lmh/20
# /language/ncd/20
# /language/phw/20
# /language/pum/20
# /language/raq/20
# /language/rav/20
# /language/wly/20
# /language/ybh/20
# /language/luu/20
# /language/ybi/20
# /language/lrr/20
# /subgroups/western-33
# /language/bhj/20
# /language/dus/20
# /language/jee/20
# /language/klr/20
# /language/kkt/20
# /language/suz/20
# /language/tdh/20
# /language/tij/20
# /language/wme/20
# /language/vay/20
# /subgroups/central-himalayan
# /subgroups/chepang-bhujel
# /language/byh/20
# /language/cdm/20
# /subgroups/kham-magar
# /subgroups/kham
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /subgroups/magar
# /language/mgp/20
# /language/mrd/20
# /subgroups/newar
# /language/new/20
# /subgroups/raute-raji
# /language/rji/20
# /language/rau/20
# /language/jnl/20
# /subgroups/thangmi-baraamu
# /language/brd/20
# /language/thf/20
# /subgroups/kiranti
# /subgroups/eastern-34
# /language/aph/20
# /language/bap/20
# /language/byw/20
# /language/rab/20
# /language/ctn/20
# /language/cur/20
# /language/cuw/20
# /language/raa/20
# /language/kle/20
# /language/lif/20
# /language/lbr/20
# /language/emg/20
# /language/raf/20
# /language/lmh/20
# /language/ncd/20
# /language/phw/20
# /language/pum/20
# /language/raq/20
# /language/rav/20
# /language/wly/20
# /language/ybh/20
# /language/luu/20
# /language/ybi/20
# /language/lrr/20
# /subgroups/western-33
# /language/bhj/20
# /language/dus/20
# /language/jee/20
# /language/klr/20
# /language/kkt/20
# /language/suz/20
# /language/tdh/20
# /language/tij/20
# /language/wme/20
# /language/vay/20
# /subgroups/bodish
# /language/goe/20
# /language/lhp/20
# /language/kkf/20
# /language/ole/20
# /language/tsj/20
# /subgroups/central-bodish
# /language/cda/20
# /language/tsk/20
# /subgroups/amdo
# /language/adx/20
# /subgroups/central-25
# /language/bod/20
# /subgroups/gtsang
# /language/dre/20
# /language/hut/20
# /language/scp/20
# /language/jul/20
# /language/kgy/20
# /language/lhm/20
# /language/loy/20
# /language/muk/20
# /language/kte/20
# /language/xsr/20
# /language/syw/20
# /language/tcn/20
# /language/ttz/20
# /subgroups/southern-37
# /language/bro/20
# /language/sgt/20
# /language/cgk/20
# /language/dzo/20
# /language/gro/20
# /language/lkh/20
# /language/lya/20
# /language/luk/20
# /language/sip/20
# /subgroups/western-39
# /language/jda/20
# /language/spt/20
# /language/sbu/20
# /subgroups/khams
# /language/khg/20
# /subgroups/unclassified-26
# /language/nao/20
# /language/thw/20
# /language/ola/20
# /subgroups/western-32
# /language/bft/20
# /language/cna/20
# /language/lbj/20
# /language/prx/20
# /language/zau/20
# /subgroups/east-bodish
# /language/dka/20
# /language/twm/20
# /subgroups/bumthang
# /language/kjz/20
# /language/tgf/20
# /language/dzl/20
# /language/xkf/20
# /language/xkz/20
# /language/npb/20
# /language/neh/20
# /subgroups/west-bodish
# /language/drq/20
# /language/kzq/20
# /subgroups/ghale
# /language/ghh/20
# /language/ghe/20
# /language/ght/20
# /subgroups/gurung-tamang
# /subgroups/gurungic
# /language/chx/20
# /language/gvr/20
# /language/npa/20
# /language/nmm/20
# /language/skj/20
# /language/ths/20
# /subgroups/tamang
# /language/taj/20
# /language/tge/20
# /language/tmk/20
# /language/tdg/20
# /subgroups/west-himalayish
# /subgroups/almora
# /language/bee/20
# /language/cdn/20
# /language/drd/20
# /language/rgk/20
# /subgroups/kinauri
# /language/bfu/20
# /language/jna/20
# /language/xns/20
# /language/kfk/20
# /language/nes/20
# /language/cik/20
# /language/lae/20
# /language/rnp/20
# /language/scu/20
# /language/ssk/20
# /language/lbf/20
# /language/tpq/20
# /subgroups/himalayan
# /subgroups/central-himalayan
# /subgroups/chepang-bhujel
# /language/byh/20
# /language/cdm/20
# /subgroups/kham-magar
# /subgroups/kham
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /subgroups/magar
# /language/mgp/20
# /language/mrd/20
# /subgroups/newar
# /language/new/20
# /subgroups/raute-raji
# /language/rji/20
# /language/rau/20
# /language/jnl/20
# /subgroups/thangmi-baraamu
# /language/brd/20
# /language/thf/20
# /subgroups/kiranti
# /subgroups/eastern-34
# /language/aph/20
# /language/bap/20
# /language/byw/20
# /language/rab/20
# /language/ctn/20
# /language/cur/20
# /language/cuw/20
# /language/raa/20
# /language/kle/20
# /language/lif/20
# /language/lbr/20
# /language/emg/20
# /language/raf/20
# /language/lmh/20
# /language/ncd/20
# /language/phw/20
# /language/pum/20
# /language/raq/20
# /language/rav/20
# /language/wly/20
# /language/ybh/20
# /language/luu/20
# /language/ybi/20
# /language/lrr/20
# /subgroups/western-33
# /language/bhj/20
# /language/dus/20
# /language/jee/20
# /language/klr/20
# /language/kkt/20
# /language/suz/20
# /language/tdh/20
# /language/tij/20
# /language/wme/20
# /language/vay/20
# /subgroups/angami-pochuri
# /language/njm/20
# /language/nri/20
# /language/nkh/20
# /language/nbi/20
# /language/nnl/20
# /language/npo/20
# /language/pmx/20
# /language/nre/20
# /language/nsm/20
# /subgroups/central-naga
# /language/njo/20
# /language/njh/20
# /language/nsa/20
# /language/yim/20
# /subgroups/central-tibeto-burman
# /subgroups/digarish
# /language/mhu/20
# /language/clk/20
# /subgroups/hrusish
# /language/hru/20
# /language/sjl/20
# /subgroups/keman
# /language/zkr/20
# /subgroups/kho-bwa
# /language/bgg/20
# /language/cvg/20
# /language/lsh/20
# /language/suv/20
# /language/onp/20
# /language/sdp/20
# /subgroups/lepcha
# /language/lep/20
# /subgroups/mijish
# /language/mxj/20
# /subgroups/nungish
# /language/nun/20
# /language/duu/20
# /language/raw/20
# /subgroups/tani
# /language/adi/20
# /language/adl/20
# /language/apt/20
# /language/mrg/20
# /language/nbt/20
# /language/njz/20
# /language/tgj/20
# /subgroups/karbi
# /language/ajz/20
# /language/mjw/20
# /subgroups/karenic
# /subgroups/central-10
# /language/bwe/20
# /language/kvq/20
# /language/ghk/20
# /language/kxf/20
# /language/eky/20
# /language/kyu/20
# /language/kvl/20
# /subgroups/northern-20
# /language/pdu/20
# /language/kvt/20
# /language/kvu/20
# /language/kvy/20
# /language/kxk/20
# /subgroups/peripheral
# /language/kjt/20
# /language/kjp/20
# /language/pww/20
# /language/pwo/20
# /language/blk/20
# /subgroups/southern-19
# /language/jkm/20
# /language/jkp/20
# /language/ksw/20
# /language/wea/20
# /subgroups/kuki-chin
# /language/cth/20
# /subgroups/central-11
# /language/cnw/20
# /language/tcp/20
# /language/pkh/20
# /subgroups/lai
# /language/bgr/20
# /language/cbl/20
# /language/cfm/20
# /language/cnh/20
# /subgroups/mizo
# /language/biu/20
# /language/hmr/20
# /language/hra/20
# /language/lus/20
# /language/sch/20
# /subgroups/maraic
# /language/sez/20
# /language/czt/20
# /language/zyp/20
# /subgroups/mara-0
# /language/clt/20
# /language/mrh/20
# /subgroups/northwestern-0
# /language/aim/20
# /language/anm/20
# /language/cdf/20
# /language/kmm/20
# /language/lmk/20
# /language/nct/20
# /language/kfw/20
# /language/nmh/20
# /language/tro/20
# /subgroups/peripheral-0
# /subgroups/northern-26
# /language/nmo/20
# /language/pub/20
# /language/ral/20
# /language/smt/20
# /subgroups/sizang
# /language/csy/20
# /language/gnb/20
# /language/vap/20
# /language/zom/20
# /subgroups/thado
# /language/pck/20
# /language/ctd/20
# /language/tcz/20
# /subgroups/southern-27
# /language/cek/20
# /language/cnk/20
# /language/weu/20
# /language/rtc/20
# /language/csj/20
# /language/csv/20
# /language/cmr/20
# /language/shl/20
# /subgroups/cho-asho
# /subgroups/asho
# /language/csh/20
# /language/clj/20
# /subgroups/cho
# /language/dao/20
# /language/ckn/20
# /language/hlt/20
# /language/mwq/20
# /language/cnb/20
# /subgroups/ngwi-burmese
# /subgroups/burmish
# /subgroups/northern-24
# /language/acn/20
# /language/hpo/20
# /language/lsi/20
# /language/mhx/20
# /language/bxd/20
# /language/atb/20
# /subgroups/southern-25
# /language/mya/20
# /language/dnv/20
# /language/int/20
# /language/rmz/20
# /language/rki/20
# /language/tco/20
# /language/tvn/20
# /subgroups/mru
# /language/anl/20
# /language/mro/20
# /subgroups/ngwi
# /subgroups/central-16
# /language/hle/20
# /language/jiy/20
# /language/jiu/20
# /language/lkc/20
# /language/lhu/20
# /language/lhi/20
# /language/ywt/20
# /language/yik/20
# /language/yit/20
# /language/ywl/20
# /language/llh/20
# /language/yne/20
# /language/lwu/20
# /language/ylm/20
# /language/lpo/20
# /language/lis/20
# /language/ycl/20
# /language/ysp/20
# /language/ymh/20
# /language/yiq/20
# /language/nuf/20
# /language/ysn/20
# /language/yta/20
# /language/ytl/20
# /language/zal/20
# /subgroups/northern-25
# /language/yna/20
# /language/yiu/20
# /language/yyz/20
# /language/ych/20
# /language/ygp/20
# /language/kaf/20
# /language/ylo/20
# /language/ywu/20
# /language/yig/20
# /language/iii/20
# /language/ysd/20
# /language/smh/20
# /language/ysy/20
# /language/ywq/20
# /subgroups/southeastern-2
# /language/yif/20
# /language/aub/20
# /language/yix/20
# /language/aza/20
# /language/yiz/20
# /language/ybk/20
# /language/ykt/20
# /language/ykl/20
# /language/ykn/20
# /language/yku/20
# /language/lgh/20
# /language/nty/20
# /language/ymi/20
# /language/ymx/20
# /language/ymq/20
# /language/ymc/20
# /language/ymz/20
# /language/yso/20
# /language/nos/20
# /language/yiv/20
# /language/nsf/20
# /language/nsd/20
# /language/nsv/20
# /language/ypa/20
# /language/ypg/20
# /language/ypo/20
# /language/yip/20
# /language/ypn/20
# /language/yhl/20
# /language/ypb/20
# /language/phh/20
# /language/ypm/20
# /language/ypp/20
# /language/yph/20
# /language/ypz/20
# /language/ysg/20
# /language/ytp/20
# /language/yzk/20
# /subgroups/southern-26
# /language/aeu/20
# /language/ahk/20
# /language/byo/20
# /language/ycp/20
# /language/cnc/20
# /language/enu/20
# /language/hni/20
# /language/how/20
# /language/ktp/20
# /language/lov/20
# /language/mpz/20
# /language/ymd/20
# /language/phq/20
# /language/sgk/20
# /language/slt/20
# /subgroups/bisoid
# /language/bzi/20
# /language/lwm/20
# /language/pho/20
# /language/pyy/20
# /subgroups/unclassified-18
# /language/lbg/20
# /language/ugo/20
# /subgroups/northeastern-tibeto-burman
# /subgroups/bai
# /language/bca/20
# /language/lay/20
# /language/bfc/20
# /language/bfs/20
# /subgroups/baima
# /language/bqh/20
# /subgroups/ersuish
# /language/ers/20
# /subgroups/naic
# /language/nmy/20
# /language/nru/20
# /language/nxq/20
# /language/sxg/20
# /subgroups/qiangic
# /language/gqi/20
# /language/mvm/20
# /language/pmi/20
# /language/pmj/20
# /language/cng/20
# /language/qxs/20
# /language/qvy/20
# /language/zhb/20
# /subgroups/rgyalrongic
# /language/ero/20
# /language/jya/20
# /language/jiq/20
# /language/jih/20
# /subgroups/tujia
# /language/tji/20
# /language/tjs/20
# /subgroups/sal
# /subgroups/boro-garo
# /language/der/20
# /language/grt/20
# /language/mef/20
# /language/tpe/20
# /subgroups/boro-tiwa
# /language/lax/20
# /subgroups/boro
# /language/brx/20
# /language/xac/20
# /subgroups/dimasa-kokborok
# /language/dis/20
# /subgroups/kok-borok
# /language/trp/20
# /language/ria/20
# /language/usi/20
# /subgroups/koch
# /language/aot/20
# /language/kdq/20
# /language/rah/20
# /language/ruh/20
# /subgroups/northern-naga
# /language/nbc/20
# /language/nqq/20
# /language/kix/20
# /language/nbe/20
# /language/lzn/20
# /language/nlq/20
# /language/njb/20
# /language/umn/20
# /language/nph/20
# /language/npg/20
# /language/nst/20
# /language/tvt/20
# /language/nnp/20
# /subgroups/dhimalish
# /language/dhi/20
# /language/txo/20
# /subgroups/jingppaw-asakia
# /subgroups/asakian
# /language/ckh/20
# /language/zkd/20
# /language/zkn/20
# /subgroups/jingphaw
# /language/kac/20
# /language/sgp/20
# /language/tcl/20
# /language/try/20
# /subgroups/kuki-chin-naga
# /language/mni/20
# /subgroups/tangkhulic
# /language/nkb/20
# /language/nng/20
# /language/nmf/20
# /language/ntx/20
# /subgroups/unclassified-5
# /language/dln/20
# /language/kbg/20
# /language/jkr/20
# /language/lba/20
# /language/nqy/20
# /language/nkf/20
# /language/pzn/20
# /language/nxk/20
# /language/lpn/20
# /language/jmn/20
# /language/npu/20
# /language/rnl/20
# /subgroups/western-naga
# /language/nkd/20
# /language/njn/20
# /language/nma/20
# /language/nme/20
# /language/nbu/20
# /language/nki/20
# /language/nzm/20
# /subgroups/western-tibeto-burman
# /subgroups/bodish
# /language/goe/20
# /language/lhp/20
# /language/kkf/20
# /language/ole/20
# /language/tsj/20
# /subgroups/central-bodish
# /language/cda/20
# /language/tsk/20
# /subgroups/amdo
# /language/adx/20
# /subgroups/central-25
# /language/bod/20
# /subgroups/gtsang
# /language/dre/20
# /language/hut/20
# /language/scp/20
# /language/jul/20
# /language/kgy/20
# /language/lhm/20
# /language/loy/20
# /language/muk/20
# /language/kte/20
# /language/xsr/20
# /language/syw/20
# /language/tcn/20
# /language/ttz/20
# /subgroups/southern-37
# /language/bro/20
# /language/sgt/20
# /language/cgk/20
# /language/dzo/20
# /language/gro/20
# /language/lkh/20
# /language/lya/20
# /language/luk/20
# /language/sip/20
# /subgroups/western-39
# /language/jda/20
# /language/spt/20
# /language/sbu/20
# /subgroups/khams
# /language/khg/20
# /subgroups/unclassified-26
# /language/nao/20
# /language/thw/20
# /language/ola/20
# /subgroups/western-32
# /language/bft/20
# /language/cna/20
# /language/lbj/20
# /language/prx/20
# /language/zau/20
# /subgroups/east-bodish
# /language/dka/20
# /language/twm/20
# /subgroups/bumthang
# /language/kjz/20
# /language/tgf/20
# /language/dzl/20
# /language/xkf/20
# /language/xkz/20
# /language/npb/20
# /language/neh/20
# /subgroups/west-bodish
# /language/drq/20
# /language/kzq/20
# /subgroups/ghale
# /language/ghh/20
# /language/ghe/20
# /language/ght/20
# /subgroups/gurung-tamang
# /subgroups/gurungic
# /language/chx/20
# /language/gvr/20
# /language/npa/20
# /language/nmm/20
# /language/skj/20
# /language/ths/20
# /subgroups/tamang
# /language/taj/20
# /language/tge/20
# /language/tmk/20
# /language/tdg/20
# /subgroups/west-himalayish
# /subgroups/almora
# /language/bee/20
# /language/cdn/20
# /language/drd/20
# /language/rgk/20
# /subgroups/kinauri
# /language/bfu/20
# /language/jna/20
# /language/xns/20
# /language/kfk/20
# /language/nes/20
# /language/cik/20
# /language/lae/20
# /language/rnp/20
# /language/scu/20
# /language/ssk/20
# /language/lbf/20
# /language/tpq/20
# /subgroups/himalayan
# /subgroups/central-himalayan
# /subgroups/chepang-bhujel
# /language/byh/20
# /language/cdm/20
# /subgroups/kham-magar
# /subgroups/kham
# /language/kif/20
# /language/kgj/20
# /language/kip/20
# /language/kjl/20
# /subgroups/magar
# /language/mgp/20
# /language/mrd/20
# /subgroups/newar
# /language/new/20
# /subgroups/raute-raji
# /language/rji/20
# /language/rau/20
# /language/jnl/20
# /subgroups/thangmi-baraamu
# /language/brd/20
# /language/thf/20
# /subgroups/kiranti
# /subgroups/eastern-34
# /language/aph/20
# /language/bap/20
# /language/byw/20
# /language/rab/20
# /language/ctn/20
# /language/cur/20
# /language/cuw/20
# /language/raa/20
# /language/kle/20
# /language/lif/20
# /language/lbr/20
# /language/emg/20
# /language/raf/20
# /language/lmh/20
# /language/ncd/20
# /language/phw/20
# /language/pum/20
# /language/raq/20
# /language/rav/20
# /language/wly/20
# /language/ybh/20
# /language/luu/20
# /language/ybi/20
# /language/lrr/20
# /subgroups/western-33
# /language/bhj/20
# /language/dus/20
# /language/jee/20
# /language/klr/20
# /language/kkt/20
# /language/suz/20
# /language/tdh/20
# /language/tij/20
# /language/wme/20
# /language/vay/20
# /language/cah/20
# /language/iqu/20
# /language/anb/20
# /language/arl/20
# /language/zro/20
# /subgroups/arabela-andoa
# /language/anb/20
# /language/arl/20

# %%
newdata[5]
# Out:
# {'ancestors': ['/subgroups/berber', '/subgroups/afro-asiatic'],
#  'children': ['/subgroups/awjila-sokna', '/subgroups/siwa'],
#  'depth': 3,
#  'descendants': ['/subgroups/awjila-sokna',
#   '/language/auj/20',
#   '/language/swn/20',
#   '/subgroups/siwa',
#   '/language/siz/20'],
#  'family': '/subgroups/afro-asiatic',
#  'id': 'eastern-3',
#  'is_language': False,
#  'name': 'Eastern',
#  'parent': '/subgroups/berber',
#  'path': '/subgroups/eastern-3'}

# %%
import csv
fields = ('path', 'id', 'name', 'is_language', 'country', 'depth', 'family', 'parent', 'ancestors',
          'children', 'descendants')
with gzip.open("ethnologue.csv.gz", "wt") as f:
    writer = csv.DictWriter(f, fields)
    writer.writeheader()
    for row in newdata:
        r = row.copy()
        # print(row)
        for i in ('ancestors', 'children', 'descendants'):
            r[i] = ' '.join(row[i])
        r['is_language'] = int(row['is_language'])
        writer.writerow(r)
